# %% [markdown]
# <a href="https://colab.research.google.com/github/prateekjain24/Public/blob/main/notebooks/Prompts_%26_RAG_Prateek.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install the required packages
! pip install tiktoken --upgrade
! pip install cohere --upgrade
! pip install openai --upgrade
! pip install ipywebrtc notebook
! pip install streamlit
! pip install transformers
! pip install llm
! pip install llama-index
! pip install newsapi-python
# Out:
# Collecting llm
#   Downloading llm-0.14-py3-none-any.whl (38 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from llm) (8.1.7)
# Requirement already satisfied: openai>=1.0 in /usr/local/lib/python3.10/dist-packages (from llm) (1.29.0)
# Collecting click-default-group>=1.2.3 (from llm)
#   Downloading click_default_group-1.2.4-py2.py3-none-any.whl (4.1 kB)
# Collecting sqlite-utils>=3.35.0 (from llm)
#   Downloading sqlite_utils-3.36-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 5.7 MB/s eta 0:00:00
# Collecting sqlite-migrate>=0.1a2 (from llm)
#   Downloading sqlite_migrate-0.1b0-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: pydantic>=1.10.2 in /usr/local/lib/python3.10/dist-packages (from llm) (2.7.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from llm) (6.0.1)
# Requirement already satisfied: pluggy in /usr/local/lib/python3.10/dist-packages (from llm) (1.5.0)
# Collecting python-ulid (from llm)
#   Downloading python_ulid-2.5.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from llm) (67.7.2)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (from llm) (23.1.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.0->llm) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.0->llm) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai>=1.0->llm) (0.27.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai>=1.0->llm) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai>=1.0->llm) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai>=1.0->llm) (4.11.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10.2->llm) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10.2->llm) (2.18.2)
# Collecting sqlite-fts4 (from sqlite-utils>=3.35.0->llm)
#   Downloading sqlite_fts4-1.0.3-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from sqlite-utils>=3.35.0->llm) (0.9.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from sqlite-utils>=3.35.0->llm) (2.8.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.0->llm) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai>=1.0->llm) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai>=1.0->llm) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai>=1.0->llm) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.0->llm) (0.14.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->sqlite-utils>=3.35.0->llm) (1.16.0)
# Installing collected packages: sqlite-fts4, python-ulid, click-default-group, sqlite-utils, sqlite-migrate, llm
# Successfully installed click-default-group-1.2.4 llm-0.14 python-ulid-2.5.0 sqlite-fts4-1.0.3 sqlite-migrate-0.1b0 sqlite-utils-3.36
# Collecting llama-index
#   Downloading llama_index-0.10.36-py3-none-any.whl (6.8 kB)
# Collecting llama-index-agent-openai<0.3.0,>=0.1.4 (from llama-index)
#   Downloading llama_index_agent_openai-0.2.4-py3-none-any.whl (13 kB)
# Collecting llama-index-cli<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_cli-0.1.12-py3-none-any.whl (26 kB)
# Collecting llama-index-core<0.11.0,>=0.10.35 (from llama-index)
#   Downloading llama_index_core-0.10.36-py3-none-any.whl (15.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.4/15.4 MB 74.4 MB/s eta 0:00:00
# Collecting llama-index-embeddings-openai<0.2.0,>=0.1.5 (from llama-index)
#   Downloading llama_index_embeddings_openai-0.1.9-py3-none-any.whl (6.0 kB)
# Collecting llama-index-indices-managed-llama-cloud<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_indices_managed_llama_cloud-0.1.6-py3-none-any.whl (6.7 kB)
# Collecting llama-index-legacy<0.10.0,>=0.9.48 (from llama-index)
#   Downloading llama_index_legacy-0.9.48-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 68.2 MB/s eta 0:00:00
# Collecting llama-index-llms-openai<0.2.0,>=0.1.13 (from llama-index)
#   Downloading llama_index_llms_openai-0.1.19-py3-none-any.whl (11 kB)
# Collecting llama-index-multi-modal-llms-openai<0.2.0,>=0.1.3 (from llama-index)
#   Downloading llama_index_multi_modal_llms_openai-0.1.6-py3-none-any.whl (5.8 kB)
# Collecting llama-index-program-openai<0.2.0,>=0.1.3 (from llama-index)
#   Downloading llama_index_program_openai-0.1.6-py3-none-any.whl (5.2 kB)
# Collecting llama-index-question-gen-openai<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_question_gen_openai-0.1.3-py3-none-any.whl (2.9 kB)
# Collecting llama-index-readers-file<0.2.0,>=0.1.4 (from llama-index)
#   Downloading llama_index_readers_file-0.1.22-py3-none-any.whl (36 kB)
# Collecting llama-index-readers-llama-parse<0.2.0,>=0.1.2 (from llama-index)
#   Downloading llama_index_readers_llama_parse-0.1.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: openai>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-agent-openai<0.3.0,>=0.1.4->llama-index) (1.29.0)
# Requirement already satisfied: PyYAML>=6.0.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (6.0.1)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (3.9.5)
# Collecting dataclasses-json (from llama-index-core<0.11.0,>=0.10.35->llama-index)
#   Downloading dataclasses_json-0.6.6-py3-none-any.whl (28 kB)
# Collecting deprecated>=1.2.9.3 (from llama-index-core<0.11.0,>=0.10.35->llama-index)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting dirtyjson<2.0.0,>=1.0.8 (from llama-index-core<0.11.0,>=0.10.35->llama-index)
#   Downloading dirtyjson-1.0.8-py3-none-any.whl (25 kB)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (2023.6.0)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (0.27.0)
# Collecting llamaindex-py-client<0.2.0,>=0.1.18 (from llama-index-core<0.11.0,>=0.10.35->llama-index)
#   Downloading llamaindex_py_client-0.1.19-py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 18.7 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (3.3)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (2.0.3)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (9.4.0)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (8.3.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (0.7.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (4.66.4)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (4.11.0)
# Collecting typing-inspect>=0.8.0 (from llama-index-core<0.11.0,>=0.10.35->llama-index)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from llama-index-core<0.11.0,>=0.10.35->llama-index) (1.14.1)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /usr/local/lib/python3.10/dist-packages (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (4.12.3)
# Collecting pypdf<5.0.0,>=4.0.1 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading pypdf-4.2.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 33.4 MB/s eta 0:00:00
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.2.0,>=0.1.4->llama-index)
#   Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Collecting llama-parse<0.5.0,>=0.4.0 (from llama-index-readers-llama-parse<0.2.0,>=0.1.2->llama-index)
#   Downloading llama_parse-0.4.2-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.35->llama-index) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.35->llama-index) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.35->llama-index) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.35->llama-index) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.35->llama-index) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.35->llama-index) (4.0.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.2.0,>=0.1.4->llama-index) (2.5)
# Requirement already satisfied: pydantic>=1.10 in /usr/local/lib/python3.10/dist-packages (from llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.35->llama-index) (2.7.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.35->llama-index) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.35->llama-index) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.35->llama-index) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.35->llama-index) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->llama-index-core<0.11.0,>=0.10.35->llama-index) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.35->llama-index) (0.14.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.35->llama-index) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.35->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.35->llama-index) (2023.12.25)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.14.0->llama-index-agent-openai<0.3.0,>=0.1.4->llama-index) (1.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.35->llama-index) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.35->llama-index) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.35->llama-index) (3.0.3)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.35->llama-index)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->llama-index-core<0.11.0,>=0.10.35->llama-index)
#   Downloading marshmallow-3.21.2-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.35->llama-index) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.35->llama-index) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->llama-index-core<0.11.0,>=0.10.35->llama-index) (2024.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->llama-index-core<0.11.0,>=0.10.35->llama-index) (1.2.1)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.35->llama-index) (24.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.35->llama-index) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.10->llamaindex-py-client<0.2.0,>=0.1.18->llama-index-core<0.11.0,>=0.10.35->llama-index) (2.18.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.35->llama-index) (1.16.0)
# Installing collected packages: striprtf, dirtyjson, pypdf, mypy-extensions, marshmallow, deprecated, typing-inspect, llamaindex-py-client, dataclasses-json, llama-index-legacy, llama-index-core, llama-parse, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-index-readers-llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-program-openai, llama-index-question-gen-openai, llama-index
# Successfully installed dataclasses-json-0.6.6 deprecated-1.2.14 dirtyjson-1.0.8 llama-index-0.10.36 llama-index-agent-openai-0.2.4 llama-index-cli-0.1.12 llama-index-core-0.10.36 llama-index-embeddings-openai-0.1.9 llama-index-indices-managed-llama-cloud-0.1.6 llama-index-legacy-0.9.48 llama-index-llms-openai-0.1.19 llama-index-multi-modal-llms-openai-0.1.6 llama-index-program-openai-0.1.6 llama-index-question-gen-openai-0.1.3 llama-index-readers-file-0.1.22 llama-index-readers-llama-parse-0.1.4 llama-parse-0.4.2 llamaindex-py-client-0.1.19 marshmallow-3.21.2 mypy-extensions-1.0.0 pypdf-4.2.0 striprtf-0.0.26 typing-inspect-0.9.0
# Collecting newsapi-python
#   Downloading newsapi_python-0.2.7-py2.py3-none-any.whl (7.9 kB)
# Requirement already satisfied: requests<3.0.0 in /usr/local/lib/python3.10/dist-packages (from newsapi-python) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0->newsapi-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0->newsapi-python) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0->newsapi-python) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0->newsapi-python) (2024.2.2)
# Installing collected packages: newsapi-python
# Successfully installed newsapi-python-0.2.7

# %%
#Import packages that will be used
from google.colab import userdata #To get the keys stored as secret in your google account
import os

# %% [markdown]
# #Tokenization
# Tokenization is the process of converting text into tokens, which are smaller pieces of text that the model can understand. These tokens can be individual words, parts of words, or even punctuation.
#
# Steps:
# 1. Initialize the tokenizer with a model pre-trained on the GPT-2 dataset.
# 2. Convert a sample text into a list of tokens.
# 3. Transform these tokens into their corresponding numerical token IDs, which are used internally by the model.
# 4. Print the original tokens and their IDs to observe the tokenization output.
# 5. Decode the token IDs back to text to demonstrate how the original text can be reconstructed from tokens.

# %%
from transformers import GPT2Tokenizer

# Initialize the tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# Example text
text = "Hello, how are you doing today?"

# Tokenize the text
tokens = tokenizer.tokenize(text)

# Convert tokens to token IDs
token_ids = tokenizer.convert_tokens_to_ids(tokens)

# Print the tokens and their corresponding IDs
print("Tokens:", tokens)
print("Token IDs:", token_ids)

# Convert token IDs back to text
decoded_text = tokenizer.decode(token_ids)
print("Decoded Text:", decoded_text)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Tokens: ['Hello', ',', 'Ġhow', 'Ġare', 'Ġyou', 'Ġdoing', 'Ġtoday', '?']
# Token IDs: [15496, 11, 703, 389, 345, 1804, 1909, 30]
# Decoded Text: Hello, how are you doing today?

# %% [markdown]
# #Embeddings
# The process includes:
# 1. Tokenizing the text: Breaking down the text into manageable pieces (tokens).
# 2. Converting tokens to IDs: Each token is assigned a unique number.
# 3. Generating embeddings: Transforming token IDs into vectors that represent each token's information.
#
# The output is a tensor with dimensions([1, 8, 768]):
# - 1: Number of sequences processed together.
# - 8: Number of tokens in the sequence.
# - 768: Length of each vector representing a token.

# %%
from transformers import GPT2Tokenizer, GPT2Model
import torch

# Initialize the tokenizer and model
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2Model.from_pretrained('gpt2')

# Example text
text = "Hello, how are you doing today?"

# Tokenize the text
tokens = tokenizer.tokenize(text)

# Convert tokens to token IDs
token_ids = tokenizer.convert_tokens_to_ids(tokens)

# Convert token IDs to a PyTorch tensor and add an extra dimension to represent the batch
input_ids = torch.tensor([token_ids])

# Pass the input IDs to the model to get the embeddings
with torch.no_grad():  # Temporarily set all the requires_grad flags to false
    outputs = model(input_ids)
    embeddings = outputs.last_hidden_state

# Print the shape of the embeddings tensor
print("Shape of Embeddings Tensor:", embeddings.shape)
# This tensor contains the embeddings for each token in the input text

# Print embeddings for the first token
print("Embeddings for the first token:", embeddings[0, 0])
# Out:
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Shape of Embeddings Tensor: torch.Size([1, 8, 768])
# Embeddings for the first token: tensor([-9.0550e-06, -1.4021e-01, -2.0845e-01, -2.8111e-02, -9.0179e-02,
#         -1.9851e-01,  4.0725e+00, -2.4899e-01, -1.7169e-01, -1.6896e-02,
#          4.5642e-01, -4.8937e-02, -4.6899e-02, -1.6776e-02, -5.8489e-02,
#          2.2157e-02, -1.8063e-01, -2.4724e-01,  6.4929e-02, -1.8779e-01,
#          1.8625e-01, -1.1250e-01, -2.7744e-01, -2.3410e-01,  9.3580e-03,
#          1.3032e-01, -2.2774e-01, -2.6420e-01,  5.5922e-02, -2.1989e-01,
#         -2.8169e-02, -8.0328e-02, -9.4422e-02, -3.5872e-01, -4.2883e-02,
#         -1.5703e-02,  2.3043e+01, -9.1412e-02, -8.3325e-02, -9.3250e-03,
#         -4.8949e-02,  3.8164e-02, -7.8332e-03, -3.3421e-01, -6.0129e-02,
#          2.4861e-01, -4.7757e-02,  2.1898e-02, -2.6603e-01,  2.3537e-01,
#         -2.3960e-02,  1.4760e-01, -1.6522e-01, -1.2762e-01, -4.6609e-02,
#          5.3239e-01,  9.1424e-02, -1.0306e-01, -1.5958e-01,  9.0476e-03,
#          6.7818e-02, -1.7447e-01,  9.0431e-02, -2.3267e-01, -1.0384e+00,
#         -1.0886e-01, -9.1550e-02, -1.9376e-01, -2.1747e-01, -1.7588e-01,
#         -1.8190e-01, -2.2122e-01, -5.2724e-03, -1.3113e-01, -5.5948e-02,
#         -1.3348e-01, -3.6275e-01, -8.2136e-01,  1.1548e-02, -9.3422e-02,
#         -3.0946e-01, -8.2352e-02, -1.5993e-02, -3.8927e-01, -6.1681e-02,
#          1.1224e-01, -2.8828e-01, -9.8928e-01,  4.9575e-02, -1.4351e-01,
#         -5.5056e-02, -1.9889e-01, -7.9988e-02, -1.0703e-01, -2.7224e-01,
#         -6.9430e-02,  8.5671e-02,  7.3009e-02,  2.4666e-02,  2.3033e-01,
#         -2.3407e-01,  3.2982e-03,  3.7990e-01, -2.0657e-01, -8.2897e-02,
#          1.5262e-02, -9.6436e-02,  3.6318e+00, -1.2501e-01, -1.1310e-01,
#         -1.0700e-01,  3.4916e-02, -1.0196e-01, -2.2886e-02, -1.1078e-01,
#          2.8867e-03, -2.8921e-01,  1.0080e-01, -4.7243e-02,  4.3584e-02,
#         -2.1214e-01,  1.5287e-01,  4.9765e-02, -4.7919e-02, -2.8710e-01,
#         -4.6097e-02, -1.6392e-01,  7.5053e-03, -4.8579e-01,  5.2097e-02,
#         -4.9569e-02,  1.4317e-01,  2.6067e-01, -1.1717e-01, -4.7788e-02,
#         -1.0623e-01, -5.1080e-02, -2.0678e-01,  6.5427e-01,  1.6841e-01,
#         -1.9387e-01,  9.9348e-02, -1.0446e+00,  2.9143e-02,  1.7844e-01,
#          2.0472e-01, -1.2757e-02, -5.0824e-02, -8.9976e-02, -1.4642e-01,
#         -1.4112e-03, -2.0945e-01, -1.5999e-01,  6.1647e-02, -3.3340e-01,
#          1.5149e-02, -1.0745e-01, -3.2016e-01,  4.5300e-02, -1.5488e-01,
#          2.4326e-01, -4.5065e-02,  6.5185e-02,  1.7042e-02, -3.4303e-01,
#          2.8008e-02, -1.7670e-01, -1.2761e+00, -5.5425e-02, -3.0901e-01,
#         -9.3096e-02, -1.1111e-01, -1.3979e-01,  3.1292e-01, -1.5457e-01,
#         -8.9526e-03, -8.5945e-02, -1.6597e-01,  4.5134e-03,  6.8452e-02,
#         -2.1685e-01, -1.2522e-01, -1.4559e-02, -1.3746e-01, -7.2453e-02,
#         -2.3061e-01, -1.0402e-01, -1.5659e-01, -5.4282e-02, -1.3121e-02,
#         -1.7202e-01, -8.1653e-02, -1.1215e-01, -8.7833e-02, -1.1339e-01,
#         -1.0917e-01,  4.9634e-02, -2.5848e-01, -3.9341e-02, -4.1624e-01,
#         -1.3004e-01,  1.9056e-01, -2.5078e-01, -3.7875e-04, -9.4763e-02,
#         -1.1995e-01, -1.6782e-01, -1.3930e-01, -1.4428e-02, -7.9488e-02,
#          1.7715e-01,  2.0003e-01, -1.6155e-01,  4.6834e-02, -1.0466e-01,
#          1.3402e-02, -3.3845e-01, -1.8727e-01, -1.5407e-01, -1.0780e-01,
#         -2.7868e-02, -4.7374e-02, -7.0992e-02, -1.3739e-01, -2.7291e-02,
#         -3.3869e-02, -1.3178e-01,  2.1552e-02,  2.8402e-02, -1.7141e-01,
#          1.3990e-01, -4.4970e-02,  1.1859e+00, -7.7360e-02, -2.2304e-02,
#         -2.8952e-01, -2.0066e-01, -7.2397e-02, -3.4428e-02, -9.0235e-02,
#          1.7311e-01,  2.5310e-01,  2.4795e-01, -1.0933e-01, -4.6152e-02,
#         -1.0981e-01, -1.3627e-01,  6.0689e-02, -4.6002e-02,  5.7064e-02,
#         -1.4859e-01, -3.0868e-01, -8.2611e-02,  3.8035e-02, -2.2160e-01,
#          1.7831e-01,  2.2842e-02,  9.6592e-02, -1.6316e-02,  6.0135e-02,
#          4.3810e-02,  1.0263e-01, -8.3501e-02,  4.8736e-02, -7.0925e-02,
#         -1.6868e-01, -9.6758e-01, -5.3411e-02, -2.2266e-01,  3.0736e-01,
#         -2.4661e-01,  8.7175e-01, -9.1210e-02, -1.2756e-02, -1.2830e-01,
#         -6.3448e-03,  1.0739e-01,  9.7104e-02, -1.2405e-01, -2.2699e-02,
#         -3.8316e-03, -1.8530e-01,  8.7628e-02, -3.4639e-02,  1.6247e-01,
#         -1.8996e-01, -2.2062e-01, -6.9275e-02, -2.5309e-01, -3.2437e-01,
#         -1.4559e-01, -1.2439e-01, -2.1173e-01, -2.6378e-02,  1.3300e-02,
#         -4.7929e-02, -5.3401e-02, -1.3890e-01, -5.6303e-02, -8.7777e-02,
#         -1.7209e-02, -2.1497e-02,  4.2182e-02,  4.3129e-02, -9.2212e-02,
#         -1.8491e-01,  1.7109e-01,  4.1504e-02, -3.5268e-01, -1.6660e-01,
#         -8.5620e-02,  5.2738e-01, -1.3615e-01, -8.9433e-02, -4.2098e+00,
#         -2.6511e-01, -1.7765e-01,  3.9622e-02, -5.9740e-02,  7.6421e-02,
#         -1.0157e-01, -2.3245e-01, -2.3433e-01, -1.1506e-01,  1.3515e-01,
#          7.5964e-02, -3.4070e-02, -6.3792e-02,  7.1463e-02, -2.0754e-01,
#         -2.5826e-01, -2.1559e-01, -5.6246e-02, -7.3141e-02,  1.5698e-01,
#         -2.3472e-01,  6.2237e-02, -1.4890e-01, -1.4191e-01, -4.9852e-02,
#         -9.7419e-02, -2.1403e-02, -3.6268e-01, -2.4960e-01, -5.8430e-02,
#          4.7466e-02, -6.3170e-02, -5.1120e-01,  1.1721e-01,  7.2454e-03,
#         -2.0152e-01,  2.8727e-01,  1.1324e-01, -2.7486e-01,  1.9978e-02,
#         -8.8405e-02, -2.8578e-01, -1.0099e-01,  8.0491e-02, -1.0841e-01,
#         -2.7576e-01, -3.2736e-01, -3.3809e-01, -3.1082e-01, -1.7863e-01,
#         -1.5407e+00, -5.7501e-02, -4.5584e-02,  9.3288e-02, -3.0945e-02,
#          1.9720e-01, -3.1587e-03,  1.9738e-02, -7.2277e-01, -8.6814e+00,
#         -1.4427e-01, -1.2990e-01,  5.7965e-01, -5.2642e-01,  3.1645e-02,
#         -8.4818e-02, -3.0096e-03,  8.6807e-03, -5.6503e-02, -3.3395e-01,
#         -6.6175e-02,  1.3998e-01, -1.7018e-02,  1.5854e-02, -7.9243e-01,
#          5.2032e-02, -2.5035e-02,  6.4225e-02, -5.4420e-01, -3.0036e-01,
#          2.5496e-02, -2.7706e-01, -1.7086e-01, -3.0765e-02,  1.5435e-02,
#         -9.6455e-02, -1.9284e-01, -1.2826e-01, -5.3901e-02, -1.7467e-01,
#         -4.1933e-02, -1.8050e-01, -2.4823e-01,  3.1589e-01, -2.2452e-02,
#         -4.5112e-01,  5.6356e-02, -1.9254e-01, -3.1695e-01, -1.5582e-01,
#         -1.2251e-01, -4.3408e-02, -1.1313e-02,  8.4138e-02, -3.6220e-02,
#         -3.1871e-01, -5.9787e-02,  2.0647e-01, -1.2798e-01, -8.6371e-02,
#         -3.9451e-02, -1.8607e-01, -9.1781e-02, -1.2482e-01, -2.5693e-01,
#          4.3956e+01, -1.2376e-01,  7.3851e-02, -1.1273e-02, -1.3344e-01,
#          2.1595e-01, -2.1129e-01, -2.5775e-01, -1.5285e-01,  9.2153e-02,
#         -4.8531e-02, -3.2467e-02,  1.7440e+00, -8.4559e-02,  1.4577e-01,
#         -1.1332e-01, -7.7927e-02,  1.6955e+00, -1.6689e-01,  1.0360e-01,
#         -1.9361e-01, -4.8921e-02, -1.2664e-02, -5.2246e-01, -1.4297e-01,
#         -2.5980e-01, -2.7674e-01, -1.1087e-01, -8.9686e-02, -2.1759e-01,
#          1.9908e-01,  1.4803e-02,  5.1319e-02, -1.3547e-01, -1.8986e-01,
#         -2.1807e-01,  2.4148e-02, -1.1752e-01, -2.1947e-01, -5.6407e-02,
#          8.6143e-02, -1.0441e-01, -7.3643e-02, -1.7931e-02, -7.7140e-02,
#         -1.6740e-01,  8.7133e-02, -3.7277e-02, -2.9740e-01, -1.5299e+00,
#         -8.5298e-01,  6.7931e-01, -1.9232e-01,  8.2375e-02, -3.3524e-02,
#         -4.4698e-02,  9.7599e-02, -6.4445e-02, -1.1827e-01, -1.5322e-01,
#         -3.6399e-02,  9.8735e-02, -2.6078e-01, -1.1114e-01, -7.8072e-02,
#          4.0861e-02,  5.5538e+01, -2.7007e-01,  1.6306e-02, -2.5143e-02,
#         -5.6052e-02, -1.6423e-01, -8.3862e-02, -1.0899e+00,  1.1925e-01,
#         -1.1742e-01, -2.6324e-03,  1.5483e-01, -8.1662e-03,  6.9492e-02,
#         -4.2825e-02, -4.0200e-01,  4.8332e-02, -2.3305e-01, -1.1708e-01,
#         -2.2300e-01, -4.9037e-02, -2.7402e-01, -1.6754e-01, -1.5285e-01,
#         -1.4246e-01, -7.5899e-02, -1.1477e-01, -1.5793e-01,  4.6632e-02,
#         -1.6474e-01, -4.1902e-01, -8.2112e-01, -4.5679e-01, -4.2560e-02,
#         -8.7126e-02, -6.9258e-02, -7.2998e-02, -2.5597e-02, -1.0875e-01,
#         -1.0423e-01, -3.1860e-02, -2.0941e-01, -1.0454e-02, -5.6281e-02,
#          2.5862e-01, -3.8112e-01,  6.1806e-02, -2.9006e-01, -2.1564e-01,
#         -1.0571e-01, -1.4415e-01, -5.2316e-02, -4.4748e-02, -2.1003e-01,
#         -7.7732e-03,  1.9289e-01, -3.4157e-02, -7.1668e-02, -9.5194e-01,
#         -1.0274e-01,  4.8498e-02,  4.2974e-02, -1.9714e-01, -2.5581e-01,
#         -1.3836e-01, -7.5689e-02, -1.6136e-01, -5.3657e-02, -9.2641e-02,
#         -1.6034e-01,  6.0745e-02, -2.2631e-01, -2.0450e-01, -4.1807e-01,
#         -1.7883e-01,  3.0889e-02, -6.6737e-04, -9.5083e-02, -8.8143e-02,
#         -5.2409e-02,  4.3537e-02, -1.1857e-01, -3.3081e-01,  6.6544e-02,
#         -3.7087e-02, -1.0688e-01,  6.4353e-02,  4.4081e-02, -2.0221e-01,
#          8.2966e-02, -5.3789e-02, -2.3687e-01,  9.0452e-02,  1.3973e-01,
#          1.0516e-01,  1.5444e-02, -2.6154e-02, -1.8054e-01,  2.7291e-02,
#         -1.0554e-01, -1.8293e-01, -3.5152e-02,  3.5411e-02, -8.3520e-02,
#         -1.1805e-01, -1.7070e-02, -1.2013e-01, -9.5703e-02,  7.2592e-02,
#         -4.4772e-02, -1.3695e-01,  1.3164e-01, -4.8653e-01,  1.3733e-01,
#          7.3252e-02, -3.1417e-02, -1.6366e-01, -4.0980e-02, -2.8278e-01,
#         -1.3710e-01, -2.6795e-01, -1.2335e-01, -4.7131e-02, -2.2019e-01,
#         -4.0999e-03, -2.2627e-03,  1.2539e-01, -2.6831e-01, -8.9477e-02,
#          6.7855e-02, -1.8683e-01, -1.6638e+00, -1.2663e-02, -2.5398e-01,
#          7.6651e-02, -2.0736e-01, -6.4220e-02, -1.2150e-01, -6.0484e-02,
#         -6.4579e-01, -3.3741e-01,  2.4007e-04, -3.6710e-01,  1.7577e-01,
#         -3.7638e-01,  8.7694e-02, -2.9426e-01, -2.7142e-01, -8.6863e-02,
#         -6.9353e-02, -1.8649e-01, -4.8745e-01, -2.5500e-02,  3.5510e-01,
#          3.4852e-02, -7.7733e-03,  3.7168e-02, -9.5169e-02,  6.8589e-03,
#          1.3552e-01,  3.4482e-02,  1.5667e-01, -1.1676e-01,  3.5998e-01,
#          2.1504e-02, -8.0935e-02, -1.9989e-01, -9.4407e-03, -7.4355e-02,
#          2.2829e-01, -1.4676e-01, -1.5662e-01,  2.8016e-01, -2.3952e-03,
#         -1.8062e-01, -3.7087e-02, -9.9943e-02, -2.8894e-02, -7.6349e-01,
#          8.1735e-04, -1.4042e-01, -2.2892e-01,  6.9898e-02,  4.1007e-01,
#         -3.6122e-01, -7.3427e-04, -1.4481e-01,  1.9850e-01, -9.6636e-02,
#         -9.2418e-02, -1.8379e-01,  4.1657e-02,  1.1862e-01, -2.0105e-02,
#         -6.4407e-02,  1.5504e-01,  3.6065e-02,  3.5232e-02, -6.5168e-02,
#         -3.3605e-02,  1.2575e-01, -7.8926e-02,  6.3649e-02, -1.2970e-01,
#          1.5996e-03, -4.3727e-02, -6.0576e-02, -4.9160e+00, -1.5809e-01,
#         -2.0152e-01, -3.9186e-01, -2.8107e-01, -2.9426e-01, -8.4658e-03,
#         -6.4386e-02, -1.1101e-01, -2.0825e-01, -1.6455e-01, -1.7948e-01,
#         -1.7492e-01, -2.5858e-01, -1.4534e-01,  5.5235e-03, -2.0723e-02,
#         -1.6640e-01,  3.0577e-02,  4.3867e-02, -2.2160e-01,  2.4761e-03,
#         -1.0618e-01,  1.6626e-01, -1.4536e-01,  2.2935e-03,  2.0714e-02,
#         -8.2141e-02, -1.9501e-01, -2.2598e-01, -1.1767e-01, -1.4294e-01,
#          1.3373e-01,  1.5329e-01, -1.0375e-02, -3.5244e-01,  2.2049e-01,
#         -2.3832e-01, -1.7189e-01, -1.8302e-01, -1.3131e-01, -2.4304e-01,
#         -8.5351e-01, -3.6947e-01, -8.5482e-02, -2.1245e-01, -3.1023e-01,
#          1.0188e-02, -1.6292e-01,  3.3717e-02, -1.4228e-01, -5.5210e-02,
#          6.3708e-02, -1.5445e-01, -3.0931e-02, -1.3326e-01,  2.1415e-01,
#         -1.6293e-02, -1.2981e-02,  8.4438e-01, -1.9952e-01, -1.5796e-02,
#         -1.5329e-01, -6.7826e-02, -1.9630e-01])

# %% [markdown]
# # Basic call to OpenAI
# ## model = model you want to use.
# Suggested options are:
# 1.   gpt-4-turbo - points to latest GPT4 turbo model - more expensive & very capable
# 2.   gpt-3.5-turbo - points to latest GPT3.5 turbo model - less expensive and ok for general tasks
#
# ## seed
# It controls the randomeness of the response. use same seed to reduce randomeness and make it reproducible
#
# ## temprature
# 0 to 1.0.
# Higher the number more creative the model will be.

# %%
import openai
from openai import OpenAI
# Set your OpenAI API key
os.environ['OPENAI_API_KEY']= userdata.get('openai_key')
client = OpenAI()

# Define the prompt
basic_prompt = "Translate the following English text to Vietnamese: 'Hello, how are you?'"

# Call the OpenAI API with required model
completion = client.chat.completions.create(
model="gpt-4o",
seed=1234,
temperature=0.3,
messages=[
      {"role": "user", "content": basic_prompt}
      ]
         )
print(completion.choices[0].message.content)
# Out:
# Xin chào, bạn khỏe không?

# %% [markdown]
# ---

# %% [markdown]
# Using LLM Python library to make it easy for calling
#
# Below fuction initialises both gpt3.5-turbo & gpt4-turbo models

# %%
import llm
def build_models():

    OPENAI_API_KEY = userdata.get('openai_key')

    gpt3_model = llm.get_model("gpt-3.5-turbo")
    gpt3_model.key = OPENAI_API_KEY

    gpt4_model = llm.get_model("gpt-4o")
    gpt4_model.key = OPENAI_API_KEY

    return gpt3_model, gpt4_model

# %% [markdown]
# #    Snowball prompt
# start with a little information, that is developed over each prompt.
#
# Use Case
# - Blogs
# - Newsletters
# - Research
# - Summaries
#
# Snowball:
#
# A --> B --> C --> D --> E --> F --> G

# %%
def prompt_chain_snowball(llm_model, base_information):
    # Snowball 1
    snowball_prompt_response_1 = llm_model.prompt(
        f"Generate a clickworthy title about this topic: '{base_information}'. Respond in JSON format {{title: 'title', topic: '{base_information}'}}",
            system="You are a famous Content Creator who understands how content virality works"
    )
    print("Snowball #1: ", snowball_prompt_response_1.text())
    # Snowball 2
    snowball_prompt_response_2 = llm_model.prompt(
        f"Generate a compelling 5 section outline given this information: '{snowball_prompt_response_1.text()}'. Respond in JSON format {{title: '<title>', topic: '<topic>', sections: ['<section1>', '<section2>', '<section3>']}}",
            system="You are an expert content writer and understands how people consume information"
    )
    print("Snowball #2: ", snowball_prompt_response_2.text())
    # Snowball 3
    snowball_prompt_response_3 = llm_model.prompt(
        f"Generate 1-2 paragraph of content for EVERY SECTION outline given this information: '{snowball_prompt_response_2.text()}'. Use examples, numbers and bullet points. Respond in JSON format {{title: '<title>', topic: '<topic>', sections: ['<section1>', '<section2>', '<section3>'], content: ['<content1>', '<content2>', '<content3>']}}",
            system="You are the expert content writer and impart impartial & detailed knowledge with your readers. You are known for sharing numbers, facts & very detailed writing."
    )
    print("Snowball #3: ", snowball_prompt_response_3.text())
    # Snowball 4
    snowball_markdown_prompt = llm_model.prompt(
        f"Generate a markdown formatted blog post given this information: '{snowball_prompt_response_3.text()}'. Respond in Markdown format Only"
    )
    print("Final Snowball: ", snowball_markdown_prompt.text())

    with open("snowball_prompt_chain.md", "w") as file:
        file.write(snowball_markdown_prompt.text())
    return snowball_markdown_prompt.text()
# Get models
gpt3_model, gpt4_model = build_models()

# Define Intital Prompt
prompt = "5 things to be aware of when renting as an expat in singapore. Location, rents, agreeements etc"
#Build snowball
article = prompt_chain_snowball(gpt4_model,prompt)
# Out:
# Snowball #1:  ```json
# {
#   "title": "5 Must-Know Tips for Expats Renting in Singapore: Navigate Locations, Rents, and Agreements Like a Pro!",
#   "topic": "5 things to be aware of when renting as an expat in singapore. Location, rents, agreeements etc"
# }
# ```
# Snowball #2:  ```json
# {
#   "title": "5 Must-Know Tips for Expats Renting in Singapore: Navigate Locations, Rents, and Agreements Like a Pro!",
#   "topic": "5 things to be aware of when renting as an expat in Singapore. Location, rents, agreements etc.",
#   "sections": [
#     {
#       "title": "1. Understanding Singapore's Rental Market",
#       "key_points": [
#         "Overview of current rental trends",
#         "Popular areas for expats: pros and cons",
#         "What drives rental prices in Singapore"
#       ]
#     },
#     {
#       "title": "2. Choosing the Right Location",
#       "key_points": [
#         "Factors to consider: proximity to work, schools, amenities",
#         "Exploring different districts and neighborhoods",
#         "Transportation links and accessibility"
#       ]
#     },
#     {
#       "title": "3. Navigating Rental Costs and Hidden Fees",
#       "key_points": [
#         "Average rental prices in key expat areas",
#         "Understanding additional costs: utilities, maintenance fees, agent fees",
#         "Tips for setting and sticking to a rental budget"
#       ]
#     },
#     {
#       "title": "4. Mastering Rental Agreements and Legalities",
#       "key_points": [
#         "Essential clauses and terms to look out for",
#         "Security deposits, duration of leases, and renewal terms",
#         "Legal rights and responsibilities of tenants and landlords"
#       ]
#     },
#     {
#       "title": "5. Tips for a Smooth Renting Experience",
#       "key_points": [
#         "How to negotiate better rental terms",
#         "Finding reliable real estate agents",
#         "Handling move-in/move-out inspections"
#       ]
#     }
#   ]
# }
# ```
# Snowball #3:  ```json
# {
#   "title": "5 Must-Know Tips for Expats Renting in Singapore: Navigate Locations, Rents, and Agreements Like a Pro!",
#   "topic": "5 things to be aware of when renting as an expat in Singapore. Location, rents, agreements etc.",
#   "sections": [
#     {
#       "title": "1. Understanding Singapore's Rental Market",
#       "key_points": [
#         "Overview of current rental trends",
#         "Popular areas for expats: pros and cons",
#         "What drives rental prices in Singapore"
#       ]
#     },
#     {
#       "title": "2. Choosing the Right Location",
#       "key_points": [
#         "Factors to consider: proximity to work, schools, amenities",
#         "Exploring different districts and neighborhoods",
#         "Transportation links and accessibility"
#       ]
#     },
#     {
#       "title": "3. Navigating Rental Costs and Hidden Fees",
#       "key_points": [
#         "Average rental prices in key expat areas",
#         "Understanding additional costs: utilities, maintenance fees, agent fees",
#         "Tips for setting and sticking to a rental budget"
#       ]
#     },
#     {
#       "title": "4. Mastering Rental Agreements and Legalities",
#       "key_points": [
#         "Essential clauses and terms to look out for",
#         "Security deposits, duration of leases, and renewal terms",
#         "Legal rights and responsibilities of tenants and landlords"
#       ]
#     },
#     {
#       "title": "5. Tips for a Smooth Renting Experience",
#       "key_points": [
#         "How to negotiate better rental terms",
#         "Finding reliable real estate agents",
#         "Handling move-in/move-out inspections"
#       ]
#     }
#   ],
#   "content": [
#     {
#       "section_title": "1. Understanding Singapore's Rental Market",
#       "text": "Singapore's rental market is known for its volatility and high prices. Rental trends fluctuate based on factors such as economic conditions and government policies. Popular areas for expats include Orchard Road, Holland Village, and Sentosa Cove. Each area has its own pros and cons; for example, Orchard Road offers a bustling environment with excellent shopping but can be noisy, while Holland Village provides a more relaxed, community vibe. Rental prices are driven by factors such as location proximity to business districts, amenities, public transportation, and the age of the property."
#     },
#     {
#       "section_title": "2. Choosing the Right Location",
#       "text": "When choosing a location, consider key factors like proximity to your workplace, international schools (if you have children), and nearby amenities such as supermarkets and healthcare. For instance, if working in CBD, areas like Marina Bay and Tanjong Pagar may be convenient. Singapore is divided into multiple districts, each with its unique characteristics – District 10 (Holland/Bukit Timah) is popular among families for its proximity to good schools. Accessibility is also crucial; the island is well connected with a comprehensive MRT network, so living near an MRT station can save time and commuting costs."
#     },
#     {
#       "section_title": "3. Navigating Rental Costs and Hidden Fees",
#       "text": "Rental costs in Singapore can significantly vary. For example, a one-bedroom apartment in Newton may cost around SGD 3,500 per month, while in Yishun, it may be around SGD 2,000. Besides rent, other costs include utilities ($100-$300 monthly), maintenance fees, and agent fees, commonly one month’s rent. It's crucial to set a budget, considering these additional costs. Tools such as the Singapore Rent Index can give a ballpark figure of average costs in various districts, helping to maintain your budget plan."
#     },
#     {
#       "section_title": "4. Mastering Rental Agreements and Legalities",
#       "text": "Understanding your rental agreement is crucial. Look out for essential clauses such as diplomatic clauses (critical if your employment is likely to change), and terms on rent increase. Security deposits usually amount to 1-2 months' rent, while lease durations are typically one or two years with renewal options. Familiarize yourself with the legal rights and responsibilities - tenants are generally responsible for minor repairs, while landlords handle major maintenance. Ensuring clarity in these areas can prevent disputes down the line."
#     },
#     {
#       "section_title": "5. Tips for a Smooth Renting Experience",
#       "text": "To secure better rental terms, negotiating with the landlord or the real estate agent can be beneficial. Research comparable rentals in the vicinity to build your case. Finding a reliable real estate agent is crucial; ask for recommendations and verify credentials. During move-in and move-out inspections, document the condition of the property with photographs and written records to avoid disputes over damages. These steps can ensure a stress-free renting experience."
#     }
#   ]
# }
# ```
# Final Snowball:  # 5 Must-Know Tips for Expats Renting in Singapore: Navigate Locations, Rents, and Agreements Like a Pro!
#
# Renting as an expat in Singapore can be both exciting and challenging. Navigating the rental market, choosing the right location, understanding costs, and mastering rental agreements are crucial for a smooth experience. Here are five essential tips to help you rent like a pro in Singapore.
#
# ## 1. Understanding Singapore's Rental Market
#
# Singapore's rental market is known for its volatility and high prices. Rental trends fluctuate based on factors such as economic conditions and government policies. Popular areas for expats include Orchard Road, Holland Village, and Sentosa Cove. Each area has its own pros and cons; for example, Orchard Road offers a bustling environment with excellent shopping but can be noisy, while Holland Village provides a more relaxed, community vibe. Rental prices are driven by factors such as location proximity to business districts, amenities, public transportation, and the age of the property.
#
# ## 2. Choosing the Right Location
#
# When choosing a location, consider key factors like proximity to your workplace, international schools (if you have children), and nearby amenities such as supermarkets and healthcare. For instance, if you're working in the CBD, areas like Marina Bay and Tanjong Pagar may be convenient. Singapore is divided into multiple districts, each with its unique characteristics – District 10 (Holland/Bukit Timah) is popular among families for its proximity to good schools. Accessibility is also crucial; the island is well-connected with a comprehensive MRT network, so living near an MRT station can save time and commuting costs.
#
# ## 3. Navigating Rental Costs and Hidden Fees
#
# Rental costs in Singapore can significantly vary. For example, a one-bedroom apartment in Newton may cost around SGD 3,500 per month, while in Yishun, it may be around SGD 2,000. Besides rent, other costs include utilities ($100-$300 monthly), maintenance fees, and agent fees, commonly one month’s rent. It's crucial to set a budget, considering these additional costs. Tools such as the Singapore Rent Index can give a ballpark figure of average costs in various districts, helping to maintain your budget plan.
#
# ## 4. Mastering Rental Agreements and Legalities
#
# Understanding your rental agreement is crucial. Look out for essential clauses such as diplomatic clauses (critical if your employment is likely to change), and terms on rent increase. Security deposits usually amount to 1-2 months' rent, while lease durations are typically one or two years with renewal options. Familiarize yourself with the legal rights and responsibilities – tenants are generally responsible for minor repairs, while landlords handle major maintenance. Ensuring clarity in these areas can prevent disputes down the line.
#
# ## 5. Tips for a Smooth Renting Experience
#
# To secure better rental terms, negotiating with the landlord or the real estate agent can be beneficial. Research comparable rentals in the vicinity to build your case. Finding a reliable real estate agent is crucial; ask for recommendations and verify credentials. During move-in and move-out inspections, document the condition of the property with photographs and written records to avoid disputes over damages. These steps can ensure a stress-free renting experience.
#
# By keeping these tips in mind, you'll be well on your way to successfully renting a home in Singapore as an expat. Happy house hunting! 🏡

# %%
from IPython.display import Markdown
# We will down-header the sections to create less confusion in this notebook
modified_article = article.replace("\n#", "\n##")
Markdown(modified_article)
# Out:
# # 5 Must-Know Tips for Expats Renting in Singapore: Navigate Locations, Rents, and Agreements Like a Pro!
#
# Renting as an expat in Singapore can be both exciting and challenging. Navigating the rental market, choosing the right location, understanding costs, and mastering rental agreements are crucial for a smooth experience. Here are five essential tips to help you rent like a pro in Singapore.
#
# ### 1. Understanding Singapore's Rental Market
#
# Singapore's rental market is known for its volatility and high prices. Rental trends fluctuate based on factors such as economic conditions and government policies. Popular areas for expats include Orchard Road, Holland Village, and Sentosa Cove. Each area has its own pros and cons; for example, Orchard Road offers a bustling environment with excellent shopping but can be noisy, while Holland Village provides a more relaxed, community vibe. Rental prices are driven by factors such as location proximity to business districts, amenities, public transportation, and the age of the property.
#
# ### 2. Choosing the Right Location
#
# When choosing a location, consider key factors like proximity to your workplace, international schools (if you have children), and nearby amenities such as supermarkets and healthcare. For instance, if you're working in the CBD, areas like Marina Bay and Tanjong Pagar may be convenient. Singapore is divided into multiple districts, each with its unique characteristics – District 10 (Holland/Bukit Timah) is popular among families for its proximity to good schools. Accessibility is also crucial; the island is well-connected with a comprehensive MRT network, so living near an MRT station can save time and commuting costs.
#
# ### 3. Navigating Rental Costs and Hidden Fees
#
# Rental costs in Singapore can significantly vary. For example, a one-bedroom apartment in Newton may cost around SGD 3,500 per month, while in Yishun, it may be around SGD 2,000. Besides rent, other costs include utilities ($100-$300 monthly), maintenance fees, and agent fees, commonly one month’s rent. It's crucial to set a budget, considering these additional costs. Tools such as the Singapore Rent Index can give a ballpark figure of average costs in various districts, helping to maintain your budget plan.
#
# ### 4. Mastering Rental Agreements and Legalities
#
# Understanding your rental agreement is crucial. Look out for essential clauses such as diplomatic clauses (critical if your employment is likely to change), and terms on rent increase. Security deposits usually amount to 1-2 months' rent, while lease durations are typically one or two years with renewal options. Familiarize yourself with the legal rights and responsibilities – tenants are generally responsible for minor repairs, while landlords handle major maintenance. Ensuring clarity in these areas can prevent disputes down the line.
#
# ### 5. Tips for a Smooth Renting Experience
#
# To secure better rental terms, negotiating with the landlord or the real estate agent can be beneficial. Research comparable rentals in the vicinity to build your case. Finding a reliable real estate agent is crucial; ask for recommendations and verify credentials. During move-in and move-out inspections, document the condition of the property with photographs and written records to avoid disputes over damages. These steps can ensure a stress-free renting experience.
#
# By keeping these tips in mind, you'll be well on your way to successfully renting a home in Singapore as an expat. Happy house hunting! 🏡

# %% [markdown]
# ---

# %% [markdown]
# # Snowball + Co-STAR
#
# ### Context(C) :
# Providing background information helps the LLM understand the specific scenario.
#
# ### Objective (O):
# Clearly defining the task directs the LLM’s focus.
#
# ### Style (S):
# Specifying the desired writing style aligns the LLM response.
#
# ### Tone (T):
# Setting the tone ensures the response resonates with the required sentiment.
#
# ### Audience (A):
# Identifying the intended audience tailors the LLM’s response to be targeted to an audience.
#
# ### Response (R):
# Providing the response format, like text or json, ensures the LLM outputs, and help build pipelines.

# %%
from IPython.display import Markdown
def costar_prompt(llm_model, prompt):
  sample_prompt ='''
    ### Context
    As a product manager at PropertyGuru, I am tasked with enhancing the online property search experience by integrating a map search feature. This feature will allow users to visually explore property listings on a map, making it easier to locate properties based on geographical preferences and proximity to amenities.

    ### Objective
    The main goal is to develop a PRD that outlines the requirements for a map search feature that is intuitive, user-friendly, and provides valuable insights into property locations, helping users make informed decisions quickly.

    ### Style
    The document should be written in a simple, clear, professional, and structured format, using technical and business language appropriate for a PRD. It should include headings, subheadings, bullet points, and tables where necessary.

    ### Tone
    The tone should be informative and assertive, reflecting the importance of the feature in enhancing the user experience on the PropertyGuru platform. Use Simple English & No Buzzwords.

    ### Audience
    The primary audience for this PRD will be the internal development team, including developers, UX/UI designers, and the quality assurance team, as well as key stakeholders such as marketing & sales teams.

    ### Response
    The desired output is a detailed PRD document in Markdown format that includes:
    - **Introduction**:Overview of the project and its importance & Value Prop for various users.
    - **User Stories**:Specific scenarios covering how different types of users will interact with the feature.
    - **Functional Requirements**:Detailed list of functional capabilities the feature must have.
    - **Non-Functional Requirements**: System-wide requirements such as performance and usability.
    - **Acceptance Criteria**:Conditions under which the feature is considered complete and ready for production.
    - **Risk Assessment**:Potential risks and their mitigation strategies.
    - **Success Metrics**:Criteria for measuring the success of the feature after deployment.
    '''
     # Snowball 1 - get a system prompt
  sys_prompt = llm_model.prompt(
        f"Generate a Detailed Persona for sytem prompt for LLMs for '{prompt}'. You are working for Propertygur. Only respond with the Persona", temperature=0.7
    )
  print("sytem prompt:",sys_prompt.text())

    # Snowball 1 - Create a Costar Prompt
  snowball_prompt_response_1 = llm_model.prompt(
        f"Generate a CoSTAR prompt for '{prompt}'. Sample response is: {sample_prompt}. '}}", temperature=0.4,
            system = sys_prompt.text()
    )
  print("Snowball #1 (CoSTAR): ", snowball_prompt_response_1.text())

    # Snowball 2 - Generate final answer
  snowball_markdown_prompt = llm_model.prompt(
        f"'{snowball_prompt_response_1.text()}'. Respond in Markdown format.Use Simple English & No Buzzwords",
            system = sys_prompt.text()
    )
  print("Final Snowball: ", snowball_markdown_prompt.text())

  with open("costar.md", "w") as file:
        file.write(snowball_markdown_prompt.text())
  return snowball_markdown_prompt.text()

# Get models
gpt3_model, gpt4_model = build_models()

# Define Intital Prompt
prompt = "Write a PRD for KYC in PropertyGuru. KYC is Know your customer where we are making login via phone number mandatory. Phone number will be verified using OTP"
#Build snowball
costar_article = costar_prompt(gpt4_model,prompt)

# We will down-header the sections to create less confusion in this notebook
modified_article = costar_article.replace("\n#", "\n##")
Markdown(modified_article)
# Out:
# sytem prompt: **Persona for LLM System Prompt:**
#
# **Name:** Akash Mehta
#
# **Title:** Senior Product Manager, User Experience & Security
#
# **Company:** PropertyGuru
#
# **Background:**
#
# Akash Mehta has over 10 years of experience in product management with a focus on user experience and security. He holds a Master's degree in Computer Science and an MBA in Product Management. He has worked with various tech companies, specializing in designing secure, user-friendly authentication systems. His career has been marked by successful implementations of KYC processes and enhancing user trust through robust security measures.
#
# **Key Responsibilities:**
#
# 1. Leading the development and implementation of the KYC (Know Your Customer) process for PropertyGuru.
# 2. Ensuring the user authentication process is seamless and secure.
# 3. Collaborating with cross-functional teams including engineering, design, and marketing to roll out new features.
# 4. Analyzing user feedback and data to continuously improve the product.
# 5. Ensuring compliance with regulatory requirements for user verification.
#
# **Goals:**
#
# 1. Implement a mandatory phone number login and verification via OTP (One-Time Password) for all PropertyGuru users.
# 2. Enhance the security and trustworthiness of the PropertyGuru platform.
# 3. Improve the user experience by simplifying the login process while ensuring high security.
# 4. Achieve a smooth transition for existing users to the new KYC process.
# 5. Minimize any disruptions or frustrations for users during the new login implementation.
#
# **Challenges:**
#
# 1. Balancing security requirements with user experience to avoid cumbersome login processes.
# 2. Ensuring the OTP verification system is reliable and quick.
# 3. Addressing any user resistance or concerns about the new mandatory phone number login.
# 4. Coordinating effectively with internal teams to ensure a seamless rollout.
# 5. Maintaining compliance with privacy laws and data protection regulations.
#
# **Success Metrics:**
#
# 1. User adoption rate of the new phone number login system.
# 2. Reduction in unauthorized access incidents.
# 3. Positive user feedback on the new login process.
# 4. High reliability and speed of OTP delivery and verification.
# 5. Compliance with all relevant regulatory requirements without negatively impacting user experience.
#
# **Communication Style:**
#
# Akash is clear, concise, and detail-oriented. He values data-driven decision-making and is adept at communicating complex technical requirements in an understandable manner. He is collaborative, always seeking input from his team and stakeholders to ensure the best outcomes for the product and its users.
#
# **Preferred Tools:**
#
# 1. Jira for project management.
# 2. Slack for team communication.
# 3. Google Analytics for user data analysis.
# 4. Looker for data visualization.
# 5. Confluence for documentation.
#
# **User-Centric Philosophy:**
#
# Akash believes that the best products are those that seamlessly integrate security with usability. He is committed to creating a frictionless user experience while ensuring that PropertyGuru users feel secure and confident in using the platform.
# Snowball #1 (CoSTAR):  ### Context
# As a product manager at PropertyGuru, I am tasked with enhancing the security and user experience of our platform by integrating a mandatory phone number login and verification process. This KYC (Know Your Customer) initiative will require users to log in using their phone numbers, which will be verified through an OTP (One-Time Password) system.
#
# ### Objective
# The main goal is to develop a PRD that outlines the requirements for implementing a mandatory phone number login and OTP verification process. This feature aims to enhance the security of user accounts, streamline the login process, and ensure compliance with regulatory requirements.
#
# ### Style
# The document should be written in a simple, clear, professional, and structured format, using technical and business language appropriate for a PRD. It should include headings, subheadings, bullet points, and tables where necessary.
#
# ### Tone
# The tone should be informative and assertive, reflecting the importance of the feature in enhancing both the security and user experience on the PropertyGuru platform. Use Simple English & No Buzzwords.
#
# ### Audience
# The primary audience for this PRD will be the internal development team, including developers, UX/UI designers, and the quality assurance team, as well as key stakeholders such as marketing & sales teams.
#
# ### Response
# The desired output is a detailed PRD document in Markdown format that includes:
# - **Introduction**: Overview of the project and its importance & Value Prop for various users.
# - **User Stories**: Specific scenarios covering how different types of users will interact with the feature.
# - **Functional Requirements**: Detailed list of functional capabilities the feature must have.
# - **Non-Functional Requirements**: System-wide requirements such as performance and usability.
# - **Acceptance Criteria**: Conditions under which the feature is considered complete and ready for production.
# - **Risk Assessment**: Potential risks and their mitigation strategies.
# - **Success Metrics**: Criteria for measuring the success of the feature after deployment.
# Final Snowball:  ```markdown
# # PropertyGuru PRD: Mandatory Phone Number Login & OTP Verification
#
# ## Introduction
#
# **Overview**
#
# This document outlines the requirements for implementing a mandatory phone number login and OTP (One-Time Password) verification process. This feature aims to enhance account security, streamline the login experience, and comply with regulatory requirements.
#
# **Value Proposition**
#
# - **Users**: Increase security, minimize risk of unauthorized access.
# - **PropertyGuru**: Ensure compliance, improve user trust in the platform.
#
# ---
#
# ## User Stories
#
# ### User Story 1: First-Time User Registration
#
# - **As a** first-time user,
# - **I want to** register using my phone number and verify it via OTP,
# - **So that** my account is secure and I can access PropertyGuru services.
#
# ### User Story 2: Existing User Transition
#
# - **As an** existing user,
# - **I want to** update my login method to phone number and verify via OTP,
# - **So that** my account security is enhanced without losing access to my data.
#
# ### User Story 3: Login Process
#
# - **As a** user,
# - **I want to** log in using my phone number and verify via OTP,
# - **So that** the login process is quick and secure.
#
# ### User Story 4: OTP Resend
#
# - **As a** user,
# - **I want to** request a new OTP if I did not receive the first one,
# - **So that** I can complete the login or registration process.
#
# ---
#
# ## Functional Requirements
#
# 1. **User Registration**
#    - Users must be able to register with their phone number.
#    - An OTP should be sent to the provided phone number for verification.
#    - The OTP must be valid for 5 minutes.
#
# 2. **Existing User Transition**
#    - Existing users must be prompted to update their login method to phone number-based.
#    - Verification via OTP should be required.
#
# 3. **Login Process**
#    - The system must allow users to enter their phone number.
#    - An OTP should be sent to the entered phone number.
#    - Users must enter the OTP to complete the login process.
#
# 4. **OTP Resend Feature**
#    - Users should have the option to request a new OTP if the initial one does not arrive.
#    - Limit OTP resend requests to a maximum of 3 within 15 minutes.
#
# 5. **Backend Validation**
#    - The backend should validate the OTP before granting access.
#    - Ensure the phone number is unique for each user.
#
# ---
#
# ## Non-Functional Requirements
#
# 1. **Performance**
#    - OTP delivery should occur within 10 seconds.
#    - The system should handle up to 1,000 OTP requests per minute.
#
# 2. **Usability**
#    - The interface should be intuitive and user-friendly.
#    - OTP entry should be straightforward with clear instructions.
#
# 3. **Security**
#    - OTP must be encrypted in transit and at rest.
#    - Implement rate-limiting to prevent abuse of OTP requests.
#
# ---
#
# ## Acceptance Criteria
#
# - **Registration Flow**
#   - Users can register using their phone number and verify it via OTP.
#   - Verification process should be successful within the defined time frame.
#
# - **Login Flow**
#   - Users can log in using their phone number and OTP.
#   - OTP should be validated correctly and grant access upon success.
#
# - **Existing Users Transition**
#   - Existing users can update their login to the new phone number method.
#   - No data loss occurs during the transition.
#
# - **Resilience**
#   - OTP resend functionality works as intended.
#   - System handles peak loads without performance degradation.
#
# ---
#
# ## Risk Assessment
#
# 1. **OTP Delivery Failures**
#    - **Risk**: OTPs not being delivered on time.
#    - **Mitigation**: Implement multiple SMS gateways and fallback mechanisms.
#
# 2. **User Resistance**
#    - **Risk**: Users resisting the switch to phone number login.
#    - **Mitigation**: Clear communication and support for users during the transition.
#
# 3. **Security Breaches**
#    - **Risk**: Potential for OTP interception.
#    - **Mitigation**: Use secure encryption methods and monitor for suspicious activities.
#
# ---
#
# ## Success Metrics
#
# 1. **User Adoption Rate**
#    - Measure the percentage of users who switch to phone number login.
#
# 2. **Unauthorized Access Incidents**
#    - Track and aim to reduce incidents of unauthorized access.
#
# 3. **User Feedback**
#    - Collect and analyze user feedback on the new login process.
#
# 4. **OTP Delivery Performance**
#    - Monitor the speed and reliability of OTP delivery.
#
# 5. **Compliance**
#    - Ensure the new system complies with all relevant regulations and privacy laws.
#
# ---
#
# *Prepared by Akash Mehta, Senior Product Manager, User Experience & Security, PropertyGuru*
# ```
# ```markdown
# ## PropertyGuru PRD: Mandatory Phone Number Login & OTP Verification
#
# ### Introduction
#
# **Overview**
#
# This document outlines the requirements for implementing a mandatory phone number login and OTP (One-Time Password) verification process. This feature aims to enhance account security, streamline the login experience, and comply with regulatory requirements.
#
# **Value Proposition**
#
# - **Users**: Increase security, minimize risk of unauthorized access.
# - **PropertyGuru**: Ensure compliance, improve user trust in the platform.
#
# ---
#
# ### User Stories
#
# #### User Story 1: First-Time User Registration
#
# - **As a** first-time user,
# - **I want to** register using my phone number and verify it via OTP,
# - **So that** my account is secure and I can access PropertyGuru services.
#
# #### User Story 2: Existing User Transition
#
# - **As an** existing user,
# - **I want to** update my login method to phone number and verify via OTP,
# - **So that** my account security is enhanced without losing access to my data.
#
# #### User Story 3: Login Process
#
# - **As a** user,
# - **I want to** log in using my phone number and verify via OTP,
# - **So that** the login process is quick and secure.
#
# #### User Story 4: OTP Resend
#
# - **As a** user,
# - **I want to** request a new OTP if I did not receive the first one,
# - **So that** I can complete the login or registration process.
#
# ---
#
# ### Functional Requirements
#
# 1. **User Registration**
#    - Users must be able to register with their phone number.
#    - An OTP should be sent to the provided phone number for verification.
#    - The OTP must be valid for 5 minutes.
#
# 2. **Existing User Transition**
#    - Existing users must be prompted to update their login method to phone number-based.
#    - Verification via OTP should be required.
#
# 3. **Login Process**
#    - The system must allow users to enter their phone number.
#    - An OTP should be sent to the entered phone number.
#    - Users must enter the OTP to complete the login process.
#
# 4. **OTP Resend Feature**
#    - Users should have the option to request a new OTP if the initial one does not arrive.
#    - Limit OTP resend requests to a maximum of 3 within 15 minutes.
#
# 5. **Backend Validation**
#    - The backend should validate the OTP before granting access.
#    - Ensure the phone number is unique for each user.
#
# ---
#
# ### Non-Functional Requirements
#
# 1. **Performance**
#    - OTP delivery should occur within 10 seconds.
#    - The system should handle up to 1,000 OTP requests per minute.
#
# 2. **Usability**
#    - The interface should be intuitive and user-friendly.
#    - OTP entry should be straightforward with clear instructions.
#
# 3. **Security**
#    - OTP must be encrypted in transit and at rest.
#    - Implement rate-limiting to prevent abuse of OTP requests.
#
# ---
#
# ### Acceptance Criteria
#
# - **Registration Flow**
#   - Users can register using their phone number and verify it via OTP.
#   - Verification process should be successful within the defined time frame.
#
# - **Login Flow**
#   - Users can log in using their phone number and OTP.
#   - OTP should be validated correctly and grant access upon success.
#
# - **Existing Users Transition**
#   - Existing users can update their login to the new phone number method.
#   - No data loss occurs during the transition.
#
# - **Resilience**
#   - OTP resend functionality works as intended.
#   - System handles peak loads without performance degradation.
#
# ---
#
# ### Risk Assessment
#
# 1. **OTP Delivery Failures**
#    - **Risk**: OTPs not being delivered on time.
#    - **Mitigation**: Implement multiple SMS gateways and fallback mechanisms.
#
# 2. **User Resistance**
#    - **Risk**: Users resisting the switch to phone number login.
#    - **Mitigation**: Clear communication and support for users during the transition.
#
# 3. **Security Breaches**
#    - **Risk**: Potential for OTP interception.
#    - **Mitigation**: Use secure encryption methods and monitor for suspicious activities.
#
# ---
#
# ### Success Metrics
#
# 1. **User Adoption Rate**
#    - Measure the percentage of users who switch to phone number login.
#
# 2. **Unauthorized Access Incidents**
#    - Track and aim to reduce incidents of unauthorized access.
#
# 3. **User Feedback**
#    - Collect and analyze user feedback on the new login process.
#
# 4. **OTP Delivery Performance**
#    - Monitor the speed and reliability of OTP delivery.
#
# 5. **Compliance**
#    - Ensure the new system complies with all relevant regulations and privacy laws.
#
# ---
#
# *Prepared by Akash Mehta, Senior Product Manager, User Experience & Security, PropertyGuru*
# ```

# %%
from IPython.display import Markdown
modified_article = costar_article.replace("\n#", "\n##")
Markdown(modified_article)
# Out:
# ```markdown
# ## PropertyGuru PRD: Mandatory Phone Number Login & OTP Verification
#
# ### Introduction
#
# **Overview**
#
# This document outlines the requirements for implementing a mandatory phone number login and OTP (One-Time Password) verification process. This feature aims to enhance account security, streamline the login experience, and comply with regulatory requirements.
#
# **Value Proposition**
#
# - **Users**: Increase security, minimize risk of unauthorized access.
# - **PropertyGuru**: Ensure compliance, improve user trust in the platform.
#
# ---
#
# ### User Stories
#
# #### User Story 1: First-Time User Registration
#
# - **As a** first-time user,
# - **I want to** register using my phone number and verify it via OTP,
# - **So that** my account is secure and I can access PropertyGuru services.
#
# #### User Story 2: Existing User Transition
#
# - **As an** existing user,
# - **I want to** update my login method to phone number and verify via OTP,
# - **So that** my account security is enhanced without losing access to my data.
#
# #### User Story 3: Login Process
#
# - **As a** user,
# - **I want to** log in using my phone number and verify via OTP,
# - **So that** the login process is quick and secure.
#
# #### User Story 4: OTP Resend
#
# - **As a** user,
# - **I want to** request a new OTP if I did not receive the first one,
# - **So that** I can complete the login or registration process.
#
# ---
#
# ### Functional Requirements
#
# 1. **User Registration**
#    - Users must be able to register with their phone number.
#    - An OTP should be sent to the provided phone number for verification.
#    - The OTP must be valid for 5 minutes.
#
# 2. **Existing User Transition**
#    - Existing users must be prompted to update their login method to phone number-based.
#    - Verification via OTP should be required.
#
# 3. **Login Process**
#    - The system must allow users to enter their phone number.
#    - An OTP should be sent to the entered phone number.
#    - Users must enter the OTP to complete the login process.
#
# 4. **OTP Resend Feature**
#    - Users should have the option to request a new OTP if the initial one does not arrive.
#    - Limit OTP resend requests to a maximum of 3 within 15 minutes.
#
# 5. **Backend Validation**
#    - The backend should validate the OTP before granting access.
#    - Ensure the phone number is unique for each user.
#
# ---
#
# ### Non-Functional Requirements
#
# 1. **Performance**
#    - OTP delivery should occur within 10 seconds.
#    - The system should handle up to 1,000 OTP requests per minute.
#
# 2. **Usability**
#    - The interface should be intuitive and user-friendly.
#    - OTP entry should be straightforward with clear instructions.
#
# 3. **Security**
#    - OTP must be encrypted in transit and at rest.
#    - Implement rate-limiting to prevent abuse of OTP requests.
#
# ---
#
# ### Acceptance Criteria
#
# - **Registration Flow**
#   - Users can register using their phone number and verify it via OTP.
#   - Verification process should be successful within the defined time frame.
#
# - **Login Flow**
#   - Users can log in using their phone number and OTP.
#   - OTP should be validated correctly and grant access upon success.
#
# - **Existing Users Transition**
#   - Existing users can update their login to the new phone number method.
#   - No data loss occurs during the transition.
#
# - **Resilience**
#   - OTP resend functionality works as intended.
#   - System handles peak loads without performance degradation.
#
# ---
#
# ### Risk Assessment
#
# 1. **OTP Delivery Failures**
#    - **Risk**: OTPs not being delivered on time.
#    - **Mitigation**: Implement multiple SMS gateways and fallback mechanisms.
#
# 2. **User Resistance**
#    - **Risk**: Users resisting the switch to phone number login.
#    - **Mitigation**: Clear communication and support for users during the transition.
#
# 3. **Security Breaches**
#    - **Risk**: Potential for OTP interception.
#    - **Mitigation**: Use secure encryption methods and monitor for suspicious activities.
#
# ---
#
# ### Success Metrics
#
# 1. **User Adoption Rate**
#    - Measure the percentage of users who switch to phone number login.
#
# 2. **Unauthorized Access Incidents**
#    - Track and aim to reduce incidents of unauthorized access.
#
# 3. **User Feedback**
#    - Collect and analyze user feedback on the new login process.
#
# 4. **OTP Delivery Performance**
#    - Monitor the speed and reliability of OTP delivery.
#
# 5. **Compliance**
#    - Ensure the new system complies with all relevant regulations and privacy laws.
#
# ---
#
# *Prepared by Akash Mehta, Senior Product Manager, User Experience & Security, PropertyGuru*
# ```

# %% [markdown]
# ---

# %% [markdown]
#
#   # Plan Execute Prompt Chain
#
# Use Case
#   - Tasks
#   - Projects
#   - Research
#   - Coding
# A -Start
# B - Plan Prompt
# C - Execute Prompt
# D - End
#
# A --> B --> C --> D

# %%
def prompt_chain_plan_execute(llm_model,task):

    plan_prompt_response = llm_model.prompt(
        f"Let's think step by step about how we would accomplish this task: '{task}'. Write all the steps & use cases in markdown format. This will be given to a programmer to code."
    )

    print(plan_prompt_response.text())

    execute_prompt_response = llm_model.prompt(
        f"create python code to solve '{task}' given this detailed plan {plan_prompt_response.text()}.  Respond with Python Code Only", system="You are an expert python programmer. Given the instructions write the code to solve the task."
    )

    print(execute_prompt_response.text())

    # write the plan and execute to a file
    with open("plan_execute_prompt_chain.py", "w") as file:
        file.write(execute_prompt_response.text())


# Get models
gpt3_model, gpt4_model = build_models()
# Define Intital Prompt
prompt = "Create a snake game in python"
#Build snowball
prompt_chain_plan_execute(gpt4_model,prompt)
# Out:
# # Step-by-Step Guide to Creating a Snake Game in Python
#
# ## Table of Contents
# 1. Introduction
# 2. Game Requirements
# 3. Setting Up the Environment
# 4. Game Design and Logical Flow
# 5. Code Structure
# 6. Detailed Steps
#     1. Initialize Pygame
#     2. Create Game Window
#     3. Define Colors and Game Variables
#     4. Create Snake and Food
#     5. Functions for Game Mechanics
#     6. Game Loop
#     7. Collision Logic
#     8. Update Snake Position
#     9. Display Score
# 7. Use Cases
# 8. Potential Enhancements
#
# ## 1. Introduction
# This document outlines the detailed steps to create a classic Snake game using Python and the Pygame library. The game involves a snake that the user controls to eat food and grow in size. The game ends if the snake collides with itself or the boundaries of the game window.
#
# ## 2. Game Requirements
# - Install Python
# - Install Pygame library (`pip install pygame`)
#
# ## 3. Setting Up the Environment
# Ensure Python and Pygame are properly installed. You can check the installation by running:
# ```bash
# python --version
# pip show pygame
# ```
#
# ## 4. Game Design and Logical Flow
# - Game Window: Display where the game takes place
# - Snake: Player's controlled object
# - Food: Object that the snake must eat to grow
# - Score: Tracks the number of food items eaten
# - Movement: Arrow keys (Up, Down, Left, Right) to control the snake
# - Collision: Ends the game
#
# ## 5. Code Structure
# The code for the Snake game will be broken down into the following parts:
# 1. Initialization and Configuration
# 2. Game Entities (Snake and Food)
# 3. Game Mechanics (movement, collisions)
# 4. Game Loop (main game logic)
# 5. Display and Update Functions
#
# ## 6. Detailed Steps
#
# ### 1. Initialize Pygame
# - Import Pygame and other necessary modules
# - Initialize Pygame using `pygame.init()`
#
# ### 2. Create Game Window
# - Set the dimensions (e.g., 600x400)
# - Create the game window using `pygame.display.set_mode`
#
# ### 3. Define Colors and Game Variables
# - Use RGB tuples to define colors (e.g., white, black, red, green)
# - Initialize game variables: snake position, direction, food position, score, and game-over state
#
# ### 4. Create Snake and Food
# - Represent the snake as a list of coordinates
# - Randomly place the food on the grid
#
# ### 5. Functions for Game Mechanics
# - `draw_snake()`: For rendering the snake
# - `spawn_food()`: For placing food at random positions
# - `check_collision()`: For checking if the snake collides with itself or the boundaries
# - `show_score()`: For displaying the current score
#
# ### 6. Game Loop
# - Create a loop that runs continuously
# - Handle events like key presses and window close
# - Update the display and call the relevant functions
# - Set frame rate using `pygame.time.Clock()`
#
# ### 7. Collision Logic
# - Check if snake’s head collides with itself or game boundaries
# - End the game if a collision occurs
#
# ### 8. Update Snake Position
# - Update the position of the snake based on the direction
# - Add new head at the front of the snake
#
# ### 9. Display Score
# - Render updated score on the screen using Pygame font
#
# ### Example Code Outline
# ```python
# import pygame
# import time
# import random
#
# # Step 1: Initialize Pygame
# pygame.init()
#
# # Step 2: Create Game Window
# window_x = 600
# window_y = 400
# game_window = pygame.display.set_mode((window_x, window_y))
#
# # Step 3: Define Colors and Game Variables
# black = (0, 0, 0)
# white = (255, 255, 255)
# red = (255, 0, 0)
# green = (0, 255, 0)
#
# snake_pos = [100, 50]
# snake_body = [[100, 50], [90, 50], [80, 50]]
# food_pos = [random.randrange(1, (window_x // 10)) * 10, random.randrange(1, (window_y // 10)) * 10]
# food_spawn = True
#
# direction = 'RIGHT'
# change_to = direction
#
# score = 0
#
# # Step 4: Create Snake and Food
# def draw_snake(snake_body):
#     for pos in snake_body:
#         pygame.draw.rect(game_window, green, pygame.Rect(pos[0], pos[1], 10, 10))
#
# def spawn_food():
#     return [random.randrange(1, (window_x // 10)) * 10, random.randrange(1, (window_y // 10)) * 10]
#
# def check_collision(snake_pos, snake_body):
#     if snake_pos[0] < 0 or snake_pos[0] > window_x - 10 or snake_pos[1] < 0 or snake_pos[1] > window_y - 10:
#         return True
#     for block in snake_body[1:]:
#         if snake_pos == block:
#             return True
#     return False
#
# def show_score():
#     font = pygame.font.SysFont('arial', 35)
#     score_surface = font.render('Score: ' + str(score), True, white)
#     game_window.blit(score_surface, [0, 0])
#
# # Step 6: Game Loop
# while True:
#     for event in pygame.event.get():
#         if event.type == pygame.QUIT:
#             pygame.quit()
#
#         elif event.type == pygame.KEYDOWN:
#             if event.key == pygame.K_UP:
#                 if not change_to == 'DOWN':
#                     change_to = 'UP'
#             elif event.key == pygame.K_DOWN:
#                 if not change_to == 'UP':
#                     change_to = 'DOWN'
#             elif event.key == pygame.K_LEFT:
#                 if not change_to == 'RIGHT':
#                     change_to = 'LEFT'
#             elif event.key == pygame.K_RIGHT:
#                 if not change_to == 'LEFT':
#                     change_to = 'RIGHT'
#
#     if change_to == 'UP':
#         direction = 'UP'
#     if change_to == 'DOWN':
#         direction = 'DOWN'
#     if change_to == 'LEFT':
#         direction = 'LEFT'
#     if change_to == 'RIGHT':
#         direction = 'RIGHT'
#
#     if direction == 'UP':
#         snake_pos[1] -= 10
#     if direction == 'DOWN':
#         snake_pos[1] += 10
#     if direction == 'LEFT':
#         snake_pos[0] -= 10
#     if direction == 'RIGHT':
#         snake_pos[0] += 10
#
#     snake_body.insert(0, list(snake_pos))
#     if snake_pos == food_pos:
#         score += 10
#         food_spawn = False
#     else:
#         snake_body.pop()
#
#     if not food_spawn:
#         food_pos = spawn_food()
#     food_spawn = True
#
#     game_window.fill(black)
#
#     draw_snake(snake_body)
#     pygame.draw.rect(game_window, red, pygame.Rect(food_pos[0], food_pos[1], 10, 10))
#
#     if check_collision(snake_pos, snake_body):
#         pygame.quit()
#
#     show_score()
#
#     pygame.display.update()
#
#     pygame.time.Clock().tick(25)
# ```
#
# ## 7. Use Cases
# - Start the game: Player initiates the game, and the snake starts moving.
# - Snake eats food: Snake grows longer, and the score increases.
# - Snake collides with itself or wall: Game over.
#
# ## 8. Potential Enhancements
# - Add levels with increasing difficulty.
# - Add obstacles for the snake to navigate.
# - Implement a pause and resume feature.
# - Incorporate different food types with varied effects.
#
# By following the above steps, a programmer can efficiently code a Snake game in Python using the Pygame library.
# ```python
# import pygame
# import time
# import random
#
# # Step 1: Initialize Pygame
# pygame.init()
#
# # Step 2: Create Game Window
# window_x = 600
# window_y = 400
# game_window = pygame.display.set_mode((window_x, window_y))
# pygame.display.set_caption('Snake Game')
#
# # Step 3: Define Colors and Game Variables
# black = (0, 0, 0)
# white = (255, 255, 255)
# red = (255, 0, 0)
# green = (0, 255, 0)
#
# snake_pos = [100, 50]
# snake_body = [[100, 50], [90, 50], [80, 50]]
# food_pos = [random.randrange(1, (window_x // 10)) * 10, random.randrange(1, (window_y // 10)) * 10]
# food_spawn = True
#
# direction = 'RIGHT'
# change_to = direction
#
# score = 0
#
# # Step 4: Create Snake and Food
# def draw_snake(snake_body):
#     for pos in snake_body:
#         pygame.draw.rect(game_window, green, pygame.Rect(pos[0], pos[1], 10, 10))
#
# def spawn_food():
#     return [random.randrange(1, (window_x // 10)) * 10, random.randrange(1, (window_y // 10)) * 10]
#
# def check_collision(snake_pos, snake_body):
#     if snake_pos[0] < 0 or snake_pos[0] > window_x - 10 or snake_pos[1] < 0 or snake_pos[1] > window_y - 10:
#         return True
#     for block in snake_body[1:]:
#         if snake_pos == block:
#             return True
#     return False
#
# def show_score():
#     font = pygame.font.SysFont('arial', 35)
#     score_surface = font.render('Score: ' + str(score), True, white)
#     game_window.blit(score_surface, [0, 0])
#
# # Step 6: Game Loop
# clock = pygame.time.Clock()
#
# while True:
#     for event in pygame.event.get():
#         if event.type == pygame.QUIT:
#             pygame.quit()
#             quit()
#         elif event.type == pygame.KEYDOWN:
#             if event.key == pygame.K_UP:
#                 if not change_to == 'DOWN':
#                     change_to = 'UP'
#             elif event.key == pygame.K_DOWN:
#                 if not change_to == 'UP':
#                     change_to = 'DOWN'
#             elif event.key == pygame.K_LEFT:
#                 if not change_to == 'RIGHT':
#                     change_to = 'LEFT'
#             elif event.key == pygame.K_RIGHT:
#                 if not change_to == 'LEFT':
#                     change_to = 'RIGHT'
#
#     if change_to == 'UP':
#         direction = 'UP'
#     if change_to == 'DOWN':
#         direction = 'DOWN'
#     if change_to == 'LEFT':
#         direction = 'LEFT'
#     if change_to == 'RIGHT':
#         direction = 'RIGHT'
#
#     if direction == 'UP':
#         snake_pos[1] -= 10
#     if direction == 'DOWN':
#         snake_pos[1] += 10
#     if direction == 'LEFT':
#         snake_pos[0] -= 10
#     if direction == 'RIGHT':
#         snake_pos[0] += 10
#
#     snake_body.insert(0, list(snake_pos))
#     if snake_pos == food_pos:
#         score += 10
#         food_spawn = False
#     else:
#         snake_body.pop()
#
#     if not food_spawn:
#         food_pos = spawn_food()
#     food_spawn = True
#
#     game_window.fill(black)
#
#     draw_snake(snake_body)
#     pygame.draw.rect(game_window, red, pygame.Rect(food_pos[0], food_pos[1], 10, 10))
#
#     if check_collision(snake_pos, snake_body):
#         pygame.quit()
#         quit()
#
#     show_score()
#
#     pygame.display.update()
#     clock.tick(25)
# ```

# %% [markdown]
# ---

# %% [markdown]
# # Using Vision
# OpenAI API to generate descriptions and tags for images, specifically tailored for use in property search platforms like PropertyGuru. It sends an image URL to the API and receives a detailed description and suggested tags in JSON format.
#
# ### Open source alternate
# https://huggingface.co/Salesforce/blip-image-captioning-large
# BLIP: Bootstrapping Language-Image Pre-training for Unified Vision-Language Understanding and Generation

# %%
from openai import OpenAI
os.environ['OPENAI_API_KEY']= userdata.get('openai_key')

def describe_image(url):
    client = OpenAI()

    response = client.chat.completions.create(
      model="gpt-4o",
      messages=[
        {
          "role": "user",
          "content": [
            {"type": "text", "text": "Describe the image and also give tags for property search in Propertyguru. Only return response in JSON Format with description, tags & total area(if floorplan). Give exact numbers where you can."},
            {
              "type": "image_url",
              "image_url": {
                "url": url,
              },
            },
          ],
        }
      ],
      max_tokens=1000,
    )
    return response.choices[0].message.content

url = "https://sg1-cdn.pgimgs.com/listing/25050587/UFLOO.147960644.V800.jpg"
url1 = "https://sg1-cdn.pgimgs.com/listing/24939766/UPHO.146721388.V800/Northwave-EC-Admiralty-Woodlands-Singapore.jpg"
response = describe_image(url)
print(response)
# Out:
# ```json
# {
#   "description": "This floor plan is for a 4-room apartment, depicting the layout and measurements of each room. The apartment includes a main bedroom, two additional bedrooms, a living room, dining area, kitchen, service yard, air-con ledge, and a house-hold shelter. There are also two bathrooms/WCs.",
#   "tags": ["4-room", "apartment", "HDB", "floor plan", "main bedroom", "bedroom", "living room", "dining area", "kitchen", "house-hold shelter", "service yard", "air-con ledge", "bathroom", "WC"],
#   "total_area": 91.5
# }
# ```

# %%
image1 = "https://sg1-cdn.pgimgs.com/listing/25050587/UPHO.147960628.V800/26A-Saint-George-s-Lane-Balestier-Toa-Payoh-Singapore.jpg"
image2 = "https://sg1-cdn.pgimgs.com/listing/25050587/UPHO.147960620.V800/26A-Saint-George-s-Lane-Balestier-Toa-Payoh-Singapore.jpg"
floorplan = "https://sg1-cdn.pgimgs.com/listing/25050587/UFLOO.147960644.V800.jpg"
other_info = ''' Size:990 Sqft. 3 Bedroom, 2 bath room.Price:S$1,150,000 . Address: 26A Saint George's Lane
  Walking distance Boon Keng MRT, 24 hours Sheng Siong Supermarket, Bendemeer Market & Food Centre, Eateries.
  Easy access to PIE, CTE.
  Hong Wen Primary, Saint Andrew School and Bendemeer Primary School are within 1 km radius.
  '''
# Convert image to text
image1_response = describe_image(image1)
image2_response = describe_image(image2)
floorplan_response = describe_image(floorplan)

# Get models
gpt3_model, gpt4_model = build_models()
# Generate transcript
execute_prompt_response = gpt4_model.prompt(
        f"Write a Listing Description for for a property listing for propertyguru. Use simple english, bullet points & emojis. info: {image1_response} \n{image2_response} \n {floorplan_response} \n {other_info}", system="You are a property agent with over 20 years of experience. You use simple language and no buzz words but explain things very clearly so that your customer get all the information they need."
    )
print(execute_prompt_response.text())
# Out:
# ### Cozy and Modern 3-Bedroom Apartment in Prime Location 🏡
#
# #### Property Details
# - **Size:** 990 sqft
# - **Price:** S$1,150,000
# - **Address:** 26A Saint George's Lane
#
# #### Features
# - **Living Room:**
#   - Modern design with contemporary look ✨
#   - Large L-shaped sofa 🛋️
#   - Ceiling fan with light 🌬️💡
#   - Wall-mounted flat-screen TV 📺
#   - Large windows with horizontal blinds 🌞
#   - Tiled flooring for easy maintenance 🧹
#   - Neutral colors for a calm and spacious feel 😌
#
# - **Dining Area:**
#   - Open-concept connected to the kitchen 🍽️
#   - Wooden dining table with chairs 🌳
#   - Well-lit with hanging lights 💡
#   - Tiled flooring for a clean look 🧼
#   - Orange door leading to the outside 🚪
#
# - **Floor Plan:**
#   - 4-room apartment, Type 1D 🏢
#   - Main bedroom and two additional bedrooms 🛏️🛏️
#   - Central dining area 🌐
#   - Kitchen and service yard 🍲👗
#   - Two bathrooms 🚿🚽
#   - Air-con ledge ❄️
#   - Household shelter 🛡️
#
# #### Amenities and Accessibility
# - **Transport:**
#   - Walking distance to Boon Keng MRT 🚆
#   - Easy access to PIE and CTE 🛣️
#
# - **Shopping and Dining:**
#   - 24-hour Sheng Siong Supermarket 🛒
#   - Bendemeer Market & Food Centre 🍜
#   - Various eateries nearby 🍽️
#
# - **Schools within 1 km:**
#   - Hong Wen Primary 🏫
#   - Saint Andrew School 🎓
#   - Bendemeer Primary School 📚
#
# #### Summary
# Ideal for families seeking a cozy, modern living space with easy access to transportation, shopping, dining, and reputable schools. Don't miss out on this fantastic opportunity! 🌟
#
# For viewing or more details, contact us today! 📞

# %%
# Get some data
# !wget https://raw.githubusercontent.com/run-llama/llama_index/main/docs/docs/examples/data/paul_graham/paul_graham_essay.txt -P data
!#wget https://raw.githubusercontent.com/bdsqqq/psykip/master/src/data/ec/index.md -P data
# !wget https://raw.githubusercontent.com/bdsqqq/psykip/master/src/data/gl/index.md -P data
# !wget https://raw.githubusercontent.com/bdsqqq/psykip/master/src/data/pem/index.md -P data
# !wget https://raw.githubusercontent.com/bdsqqq/psykip/master/src/data/sw/index.md -P data
# !wget https://raw.githubusercontent.com/bdsqqq/psykip/master/src/data/twh/index.md -P data

# %%
import os.path
from llama_index.core import (
    VectorStoreIndex,
    SimpleDirectoryReader,
    StorageContext,
    load_index_from_storage,
)

# check if storage already exists
PERSIST_DIR = "./storage"
if not os.path.exists(PERSIST_DIR):
    # load the documents and create the index
    documents = SimpleDirectoryReader("data").load_data()
    index = VectorStoreIndex.from_documents(documents)
    # store it for later
    index.storage_context.persist(persist_dir=PERSIST_DIR)
else:
    # load the existing index
    storage_context = StorageContext.from_defaults(persist_dir=PERSIST_DIR)
    index = load_index_from_storage(storage_context)

# Either way we can now query the index
query_engine = index.as_query_engine()
response = query_engine.query("who is the author?")
print(response)
# Out:
# The author is Epictetus.

# %% [markdown]
# # NewAPI Test
# https://newsapi.org/docs/client-libraries/python

# %%
import requests

url = "https://newsapi.org/v2/everything"
params = {
    "q": "Property Singapore",
    "from": "2024-04-20",
    "sortBy": "relevancy",
    "searchIn":"content",
    "apiKey": userdata.get('NewsAPI')
}

response = requests.get(url, params=params)
data = response.json()
print(data)
for article in data['articles']:
    print(article['title'],'\n','\n', article['url'],'\n######\n')
# Now you can use 'data' to process or display your articles

# %%
# Out:
# {'status': 'ok', 'totalResults': 44, 'articles': [{'source': {'id': None, 'name': 'Forbes'}, 'author': 'Isabelle Kliger, Contributor, \n Isabelle Kliger, Contributor\n https://www.forbes.com/sites/isabellekliger/', 'title': 'Crazy Rich Asians: This Is Nassim Road, Singapore’s Most Expensive Street', 'description': "In Singapore's most expensive residential area, you will find exclusive shops, restaurants and hotels, as well as the Singapore Botanic Gardens.", 'url': 'https://www.forbes.com/sites/isabellekliger/2024/04/22/crazy-rich-asians-this-is-nassim-road-singapores-most-expensive-street/', 'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/66180091f2d1a02b07ad6da2/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds', 'publishedAt': '2024-04-22T12:29:29Z', 'content': 'This quiet, leafy road may not look like much on first glance. Scratch the surface and you will discover more multi-million-dollar mansions than you can shake a Hermès purse at and a neighborhood ful… [+5946 chars]'}, {'source': {'id': None, 'name': 'Forbes'}, 'author': 'DBS Bank contributor, Brand Contributor, \n DBS Bank contributor, Brand Contributor\n https://www.forbes.com/sites/dbs-wealth-management/people/dbsbankcontributor/', 'title': 'A Springboard To The World Of The Ultra-Wealthy', 'description': 'DBS Treasures provides affluent individuals with a guided path toward the world of private banking', 'url': 'https://www.forbes.com/sites/dbs-wealth-management/2024/04/22/a-springboard-to-the-world-of-the-ultra-wealthy/', 'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/66100107dbc4b7a444f476d5/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds', 'publishedAt': '2024-04-22T12:56:28Z', 'content': 'DBS Treasures provides affluent individuals with a guided path toward the world of private banking.\r\nYeo Wenxian, Head of DBS Treasures Singapore\r\nDBS\r\nAffluent individuals have ambitious goals for t… [+6893 chars]'}, {'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'Denise Wee', 'title': 'Hong Kong Bankers Face More Job Cuts on China Slowdown, High Pay', 'description': '(Bloomberg) -- Hong Kong investment bankers could face more job cuts as the slowdown in China deals persists and employers look to trim highly compensated...', 'url': 'https://finance.yahoo.com/news/hong-kong-bankers-face-more-000000527.html', 'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/_uvEgPBfiBiIflN8m37_hA--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD04MDA-/https://media.zenfs.com/en/bloomberg_markets_842/2bc71ec13eef1a9baf7924ebcfdb7591', 'publishedAt': '2024-04-22T00:00:00Z', 'content': '(Bloomberg) -- Hong Kong investment bankers could face more job cuts as the slowdown in China deals persists and employers look to trim highly compensated staff, according to Bloomberg Intelligence.\r… [+2062 chars]'}, {'source': {'id': None, 'name': 'CNA'}, 'author': None, 'title': 'More construction firms going bust after pandemic, say liquidators', 'description': 'The sector is still reeling from the aftermath of COVID-19 and a slump in overseas investments, on top of dealing with higher costs.', 'url': 'https://www.channelnewsasia.com/singapore/construction-building-contractors-bust-debts-after-pandemic-liquidators-4282961', 'urlToImage': 'https://onecms-res.cloudinary.com/image/upload/s--jV8DBUxO--/f_auto,q_auto/c_fill,g_auto,h_676,w_1200/v1/cna-migration/file-photo-of-construction-cranes-at-a-construction-site.jpg?itok=XFLztrMb', 'publishedAt': '2024-04-22T09:35:21Z', 'content': 'HIT BY DELAYED PANDEMIC WOES\r\nLiquidators CNA spoke to said that the effect of delays due to the pandemic are now being felt as affected projects enter completion phase and disputes over delays and c… [+3588 chars]'}, {'source': {'id': None, 'name': 'CNA'}, 'author': None, 'title': "'She was taken in such a horrible way': Family of Singapore woman killed in Spain opens up about their loss", 'description': "Ms Audrey Fang's brother and cousin say they had never heard of ...
# Crazy Rich Asians: This Is Nassim Road, Singapore’s Most Expensive Street
#
#  https://www.forbes.com/sites/isabellekliger/2024/04/22/crazy-rich-asians-this-is-nassim-road-singapores-most-expensive-street/
# ######
#
# A Springboard To The World Of The Ultra-Wealthy
#
#  https://www.forbes.com/sites/dbs-wealth-management/2024/04/22/a-springboard-to-the-world-of-the-ultra-wealthy/
# ######
#
# Hong Kong Bankers Face More Job Cuts on China Slowdown, High Pay
#
#  https://finance.yahoo.com/news/hong-kong-bankers-face-more-000000527.html
# ######
#
# More construction firms going bust after pandemic, say liquidators
#
#  https://www.channelnewsasia.com/singapore/construction-building-contractors-bust-debts-after-pandemic-liquidators-4282961
# ######
#
# 'She was taken in such a horrible way': Family of Singapore woman killed in Spain opens up about their loss
#
#  https://www.channelnewsasia.com/singapore/audrey-fang-singaporean-woman-killed-spain-family-4282691
# ######
#
# Hong Kong's bankers can earn 70% more than their peers in Singapore—and that's putting them at risk of layoffs
#
#  https://fortune.com/asia/2024/04/22/hong-kong-bankers-earn-more-than-singapore-more-at-risk-of-layoffs/
# ######
#
# U.S. hotel performance for March 2024
#
#  https://www.hospitalitynet.org/news/4121545.html
# ######
#
# Landmark Hotels & Suites in UAE upgrades to Hotelogix Cloud to centralize group operations
#
#  https://www.hospitalitynet.org/news/4121565.html
# ######
#
# Events driving hotel performance in Adelaide; bookings during LIV Golf at 72%
#
#  https://www.hospitalitynet.org/news/4121575.html
# ######
#
# ‘No need to be concerned’ about Hong Kong property market: JLL global CEO
#
#  https://biztoc.com/x/5eafb223eb29f71b
# ######
#
# Boeing and Baltimore Bridge Scandals: Monopolization and Criminal Negligence?
#
#  https://www.nakedcapitalism.com/2024/04/boeing-and-baltimore-bridge-scandals-monopolization-and-criminal-negligence.html
# ######
#
# Chinese developer Landsea misses offshore notes redemption
#
#  https://www.marketscreener.com/quote/stock/LANDSEA-GREEN-MANAGEMENT--6158860/news/Chinese-developer-Landsea-misses-offshore-notes-redemption-46487193/
# ######
#
# Lionheart Capital to Acquire Sunseeker From Wanda Group
#
#  https://www.luxuo.com/homepage-slider/wanda-group-avoids-bankruptcy-by-selling-sunseeker-to-lionheart-capital-in-multi-million-dollar-deal.html
# ######
#
# Keppel Ltd. (KPELF) To Go Ex-Dividend on April 25th
#
#  https://www.etfdailynews.com/2024/04/21/keppel-ltd-kpelf-to-go-ex-dividend-on-april-25th/
# ######
#
# CapitaLand China Trust : Presentation Slides (1982 KB)
#
#  https://www.marketscreener.com/quote/stock/CAPITALAND-CHINA-TRUST-6499384/news/CapitaLand-China-Trust-Presentation-Slides-1982-KB-46496012/
# ######
#
# Real Estate Decarbonisation Platform Accacia Raises US$6.5m Pre-A Round Led by Illuminate Financial
#
#  https://financialpost.com/pmn/business-wire-news-releases-pmn/real-estate-decarbonisation-platform-accacia-raises-us6-5m-pre-a-round-led-by-illuminate-financial
# ######
#
# MediaAlpha (NYSE:MAX) and Grab (NASDAQ:GRAB) Head-To-Head Survey
#
#  https://www.etfdailynews.com/2024/04/21/mediaalpha-nysemax-and-grab-nasdaqgrab-head-to-head-survey/
# ######
#
# Maxeon Solar files patent suit against Hanwha Q CELLS
#
#  https://www.investing.com/news/company-news/maxeon-solar-files-patent-suit-against-hanwha-q-cells-93CH-3389062
# ######
#
# Head-To-Head Comparison: Alset (AEI) and Its Rivals
#
#  https://www.etfdailynews.com/2024/04/21/head-to-head-comparison-alset-aei-and-its-rivals/
# ######
#
# Alset (AEI) and Its Rivals Critical Review
#
#  https://www.etfdailynews.com/2024/04/22/alset-aei-and-its-rivals-critical-review/
# ######
#
# China's steel sector has bigger worries than Biden tariff hike
#
#  https://www.marketscreener.com/news/latest/China-s-steel-sector-has-bigger-worries-than-Biden-tariff-hike-46487672/
# ######
#
# ASMPT (OTCMKTS:ASMVF) and Amtech Systems (NASDAQ:ASYS) Critical Review
#
#  https://www.etfdailynews.com/2024/04/21/asmpt-otcmktsasmvf-and-amtech-systems-nasdaqasys-critical-review/
# ######
#
# China's strong iron ore imports diverge from weak steel output: Russell
#
#  https://www.marketscreener.com/news/latest/China-s-strong-iron-ore-imports-diverge-from-weak-steel-output-Russell-46488223/
# ######
#
# Hong Leong Finance : Response to question received from Shareholder
#
#  https://www.marketscreener.com/quote/stock/HONG-LEONG-FINANCE-LIMITE-6494564/news/Hong-Leong-Finance-Response-to-question-received-from-Shareholder-46487801/
# ######
#
# ACI Worldwide : 2023 ACI Worldwide Annual Report
#
#  https://www.marketscreener.com/quote/stock/ACI-WORLDWIDE-INC-11158/news/ACI-Worldwide-2023-ACI-Worldwide-Annual-Report-46491602/
# ######
#
# China's steel sector has bigger worries than Biden tariff hike
#
#  https://www.investing.com/news/economy/chinas-steel-sector-has-bigger-worries-than-biden-tariff-hike-3387723
# ######
#
# Walker & Dunlop (NYSE:WD) and Bitdeer Technologies Group (NASDAQ:BTDR) Head to Head Survey
#
#  https://www.etfdailynews.com/2024/04/21/walker-dunlop-nysewd-and-bitdeer-technologies-group-nasdaqbtdr-head-to-head-survey/
# ######
#
# What became of communism in Vietnam?
#
#  https://www.americanthinker.com/blog/2024/04/what_became_of_communism_in_vietnam.html
# ######
#
# Fortune Real Estate Investment Trust : ESG Report 2023
#
#  https://www.marketscreener.com/quote/stock/FORTUNE-REAL-ESTATE-INVES-6727695/news/Fortune-Real-Estate-Investment-Trust-ESG-Report-2023-46491094/
# ######
#
# Take Five: Dancing to the dollar's beat
#
#  https://www.investing.com/news/economy/take-five-dancing-to-the-dollars-beat-3387830
# ######
#
# Accacia, a decarbonisation platform focusing on the real estate raises $6.5 million
#
#  https://economictimes.indiatimes.com/industry/services/property-/-cstruction/accacia-a-decarbonisation-platform-focusing-on-the-real-estate-raises-6-5-million/articleshow/109504082.cms
# ######
#
# The Conversation: What Makes A Powerful Watch Tick
#
#  https://www.luxuo.com/homepage-slider/the-conversation-what-makes-a-powerful-watch-tick.html
# ######
#
# Vontobel Holding Ltd. Acquires New Shares in Everest Group, Ltd. (NYSE:EG)
#
#  https://www.etfdailynews.com/2024/04/21/vontobel-holding-ltd-acquires-new-shares-in-everest-group-ltd-nyseeg/
# ######
#
# OVERSEA CHINESE BANKING Corp Ltd Buys New Position in Everest Group, Ltd. (NYSE:EG)
#
#  https://www.etfdailynews.com/2024/04/22/oversea-chinese-banking-corp-ltd-buys-new-position-in-everest-group-ltd-nyseeg/
# ######
#
# Cambridge Trust Co. Acquires New Position in Everest Group, Ltd. (NYSE:EG)
#
#  https://www.etfdailynews.com/2024/04/20/cambridge-trust-co-acquires-new-position-in-everest-group-ltd-nyseeg/
# ######
#
# Americas Family Offices Directory 2024: Detailed Profiles of 1,000+ Single Family Offices in North America & South America – ResearchAndMarkets.com
#
#  https://financialpost.com/pmn/business-wire-news-releases-pmn/americas-family-offices-directory-2024-detailed-profiles-of-1000-single-family-offices-in-north-america-south-america-researchandmarkets-com
# ######
#
# ASLAN Pharmaceuticals Announces Positive Interim Results From Phase 2 Study of Eblasakimab in Dupilumab-Experienced Atopic Dermatitis Patients
#
#  https://www.globenewswire.com/news-release/2024/04/22/2866887/0/en/ASLAN-Pharmaceuticals-Announces-Positive-Interim-Results-From-Phase-2-Study-of-Eblasakimab-in-Dupilumab-Experienced-Atopic-Dermatitis-Patients.html
# ######
#
# ASLAN PHARMACEUTICALS : ANNOUNCES POSITIVE INTERIM RESULTS FROM PHASE 2 STUDY OF EBLASAKIMAB IN DUPILUMAB-EXPERIENCED ATOPIC DERMATITIS PATIENTS - Form 6-K
#
#  https://www.marketscreener.com/quote/stock/ASLAN-PHARMACEUTICALS-LIM-43214687/news/ASLAN-PHARMACEUTICALS-ANNOUNCES-POSITIVE-INTERIM-RESULTS-FROM-PHASE-2-STUDY-OF-EBLASAKIMAB-IN-DUPI-46491702/
# ######
#
# UFC and WWE "knock out" their competitors in terms of revenue, says Forbes
#
#  https://www.marca.com/en/ufc/2024/04/20/662400c146163f25768b45df.html
# ######
#
# Meta Platforms gets billions from China without headaches many U.S. companies face there
#
#  https://www.cnbc.com/2024/04/22/meta-platforms-gets-billions-from-china-without-headaches-many-us-companies-face-there.html
# ######
#
# Cork’s most luxurious hotel: ‘People expect Castlemartyr to be 100pc all the time. I agree with them’
#
#  https://www.independent.ie/business/corks-most-luxurious-hotel-people-expect-castlemartyr-to-be-100pc-all-the-time-i-agree-with-them/a1929757899.html
# ######
#
# Is the NRI dream fading? Find out how it is becoming more difficult for Indians seeking higher education, jobs abroad
#
#  https://economictimes.indiatimes.com/wealth/save/is-the-nri-dream-fading-find-out-how-it-is-becoming-more-difficult-for-indians-seeking-higher-education-jobs-abroad/articleshow/109450118.cms
# ######
#
# Barneys New York’s Phyllis Pressman Dead at 95
#
#  http://wwd.com/fashion-news/designer-luxury/barneys-new-york-phyllis-pressman-dead-at-1236322899/
# ######
#
# Wife of Sea billionaire Forrest Li to buy good class bungalow near Botanic Gardens for $42.5m
#
#  https://www.straitstimes.com/business/wife-of-sea-billionaire-forrest-li-to-buy-good-class-bungalow-near-botanic-gardens-for-425-million
# ######

# %%
import requests
from bs4 import BeautifulSoup
from openai import OpenAI

# Initialize the OpenAI client (ensure your API key is correctly set in your environment variables)
gpt3_model, gpt4_model = build_models()

# Example data structure, replace this with the actual API call response if needed


summaries = []

for article in data['articles']:
    # Fetch each webpage
    response = requests.get(article['url'])

    if response.status_code == 200:
        # Parse the webpage content with BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')

        # Extract the main text from the webpage, you might need to adjust the tag depending on the structure of the webpages
        main_content = soup.find_all('p')  # Assuming the main content is in <p> tags
        text_content = ' '.join([p.text for p in main_content])

        # Send the content of the webpage to OpenAI's GPT for summarization
        summary_response = gpt4_model.prompt( f"Summarize this text only if it is related to Property & Real Estate in South East Asia. Otherwise return:NA. Text:{text_content[:4000]}"
           )
        summaries.append(summary_response.text())
    else:
        summaries.append("Failed to fetch the webpage.")

# Output the summaries
for summary in summaries:
    print(summary)
# Out:
# This text details Nassim Road in Singapore, renowned for being the most exclusive and expensive residential area in the city-state, often labeled as Singapore's billionaire's row. Highlighting the lavish Good Class Bungalows (GCBs) that populate this street, the text explains the specific criteria a house must meet to be classified as a GCB, such as a minimum land area of 1,400 square meters and a height restriction of no more than two stories, within the city's designated GCB areas. It also touches on the high concentration of wealth in Singapore, referencing the city's ranking as the world’s fifth-wealthiest and its substantial population of millionaires and billionaires. Moreover, it provides insights into the lifestyle and amenities in and around Nassim Road, including the proximity to the Singapore Botanic Gardens, a UNESCO World Heritage site, and the luxury shopping experiences available at Orchard Road. The existence of embassies and historical residences along Nassim Road is mentioned, highlighting the area's significance beyond just residential appeal. Additionally, it briefly mentions the opening of the Conrad Singapore Orchard hotel, reflecting the exclusive atmosphere of Nassim Road.
# NA
# NA
# The construction sector in Singapore is experiencing significant difficulties due to the aftermath of COVID-19, a decrease in overseas investments, and increased costs. Liquidators have observed a rise in construction companies going bankrupt, exceeding pre-pandemic levels. The high interest rate environment, along with surges in labor and material costs by over 35%, has pressured companies like TA Corporation to close subsidiaries and sell assets at a loss. The sector faces challenges such as global supply chain disruptions, increased costs, foreign worker quota limitations, and the strong Singapore dollar affecting competitiveness. There's also pressure to meet project deadlines amidst these challenges, leading to predictions of more insolvencies and restructurings in the construction industry. The outlook appears particularly bleak for general contractors, with cooling residential markets expected to reduce new development projects, impacting demand for construction services. A business survey indicated that 10% of the construction sector is facing severe credit challenges, highlighting the financial strains on the industry.
# NA
# NA
# NA
# NA
# NA
# Despite facing challenges such as social unrest, pandemic restrictions, and geopolitical tensions for four years, Hong Kong remains an attractive top financial hub, according to Christian Ulbrich, CEO and president of the Chicago-based JLL. Even though its status as a leading property market in the world has somewhat diminished, Hong Kong still holds numerous advantages.
#
# #hongkong #christianulbrich #jll #asiapacific #singapore #ulbrich #hongkongs #beijing
# NA
# Failed to fetch the webpage.
# NA
# NA
# Failed to fetch the webpage.
# Failed to fetch the webpage.
# NA
# NA
# NA
# NA
# Failed to fetch the webpage.
# NA
# Failed to fetch the webpage.
# Failed to fetch the webpage.
# Failed to fetch the webpage.
# NA
# NA
# NA
# Failed to fetch the webpage.
# NA
# NA
# NA
# NA
# NA
# NA
# Failed to fetch the webpage.
# NA
# Failed to fetch the webpage.
# NA
# NA
# NA
# NA
# NA
# Failed to fetch the webpage.

# %%
def prompt_chain_plan_execute(llm_model,task):

    plan_prompt_response = llm_model.prompt(
        f"Let's think step by step about how we would accomplish this task: '{task}'. Write all the steps & use cases in markdown format. This will be given to a programmer to code."
    )

    print(plan_prompt_response.text())

    execute_prompt_response = llm_model.prompt(
        f"create python code to solve '{task}' given this detailed plan {plan_prompt_response.text()}.  Respond with Python Code Only", system="You are an expert python programmer. Given the instructions write the code to solve the task."
    )

    qa_prompt_response = llm_model.prompt(
        f"Given the code '{execute_prompt_response.text()}' Give detailed feedback to improve it.  Respond in Markdown Format", system="You are an expert QA. Given the instructions check the code to find error and improvements."
    )
    final_execute_prompt_response = llm_model.prompt(
        f"Given the feedback '{qa_prompt_response.text()}' for code {execute_prompt_response.text()}. Give the improved python code. Respond with Python Code Only", system="You are an expert python programmer. Given the instructions write the code to solve the task."
    )
    print(final_execute_prompt_response.text())

    # write the plan and execute to a file
    with open("plan_execute_prompt_chain.py", "w") as file:
        file.write(final_execute_prompt_response.text())


# Get models
gpt3_model, gpt4_model = build_models()
# Define Intital Prompt
prompt = "Create a GenAI Streamlit app for Product Managers. In the app PM will be able to choose from 3 functions: 1. Create a PRD 2. Improve the PRD 3. Brainstorm on an Idea"
#Build snowball
prompt_chain_plan_execute(gpt4_model,prompt)
# Out:
# # GenAI Streamlit App for Product Managers
#
# ## Overview
#
# The goal of this project is to create a Streamlit app tailored for Product Managers (PMs). The app will leverage Generative AI to assist PMs in creating, improving, and brainstorming Product Requirement Documents (PRDs). It will feature a straightforward and user-friendly interface that allows PMs to select from three primary functions:
#
# 1. Create a PRD
# 2. Improve the PRD
# 3. Brainstorm on an Idea
#
# The app aims to enhance the productivity and creativity of PMs by providing AI-assisted writing and idea generation.
#
# ## Requirements
#
# - Python 3.6+
# - Streamlit
# - OpenAI's GPT (or any equivalent AI model) for generating and improving text.
# - A text editor library for Python that supports markdown (for editing PRDs).
# - Basic web development knowledge (HTML/CSS) for UI enhancements.
# - Understanding of product management principles to accurately implement the functionality.
#
# ## High-Level Steps
#
# 1. **Setup Development Environment**:
#     - Ensure Python 3.6+ is installed.
#     - Create a virtual environment and activate it.
#     - Install Streamlit, OpenAI's Python package, and any other necessary packages.
#
# 2. **Initialize a Streamlit App**:
#     - Create a new Python script (e.g., `app.py`).
#     - Import Streamlit and other required libraries.
#     - Setup basic Streamlit app structure with a title and description.
#
# 3. **Implement the Main Interface**:
#     - Use `streamlit.sidebar.selectbox` to allow the user to choose between the 3 functions: Create a PRD, Improve the PRD, and Brainstorm on an Idea.
#     - Display an appropriate interface based on the selected function.
#
# 4. **Create PRD Functionality**:
#     - Provide a text input field or a markdown editor for users to input basic ideas or keywords.
#     - Implement a button to trigger the AI model.
#     - Use the AI model to generate a basic structure or template of a PRD based on the input.
#     - Allow the user to edit and refine the generated PRD within the app.
#
# 5. **Improve PRD Functionality**:
#     - Allow users to paste or type in their existing PRD into a text input field or markdown editor.
#     - Implement a button to trigger the AI model for improvements.
#     - The AI model should analyze the text and suggest improvements, enhancements, or identify missing elements.
#     - Allow users to accept, reject, or edit the AI's suggestions.
#
# 6. **Brainstorm on an Idea Functionality**:
#     - Provide a text input field for users to describe their idea or the problem they want to solve.
#     - Implement a button to trigger idea generation.
#     - The AI should generate multiple ideas or approaches to solve the problem or exploit the idea, presented in a list or bullet points.
#     - Allow users to select, refine, or expand on these ideas within the app.
#
# 7. **Additional Features**:
#     - Implement saving and loading functionality, allowing users to save their work and return to it later.
#     - Provide options to export the final PRD or brainstorming session to a PDF or markdown file.
#
# 8. **Testing**:
#     - Test each functionality thoroughly to ensure accuracy and reliability of the AI-generated content.
#     - Verify the app's user interface is intuitive and bug-free.
#
# 9. **Deployment**:
#     - Prepare the application for deployment.
#     - Use Streamlit sharing or a similar service to deploy the app.
#     - Ensure the deployment environment has sufficient resources to support the AI model's requirements.
#
# ## Use Cases
#
# 1. **Creating a New PRD**:
#     - The user inputs a series of keywords or a brief description of the product idea.
#     - The app generates a structured outline of a PRD, including sections like Objective, Background, Scope, and Specifications.
#     - The user refines the document within the app.
#
# 2. **Improving an Existing PRD**:
#     - The user pastes their existing PRD into the app.
#     - The app analyzes the document and suggests improvements or highlights missing elements.
#     - The user incorporates these suggestions into the document.
#
# 3. **Brainstorming Session**:
#     - The user inputs a problem statement or a rough idea.
#     - The AI generates multiple innovative ideas or approaches to the problem.
#     - The user selects and expands on these ideas to develop a new project or product concept.
#
# ## Implementation Notes
#
# - **AI Model Selection**: Choose an AI model that is versatile enough to handle text generation (for creating and brainstorming) and text analysis (for improving PRDs). OpenAI's GPT models are a good starting point.
# - **User Interface**: Ensure the user interface is clean, intuitive, and guides the PM through the process without overwhelming them with options.
# - **Data Security and Privacy**: Make sure the app does not store sensitive information without user consent, especially since PRDs can contain confidential product plans.
# - **Feedback Mechanism**: Implement a way to collect user feedback within the app to continually improve the AI algorithms and user experience.
#
# This project outline provides a comprehensive guide for a developer to create a GenAI Streamlit app designed specifically for Product Managers, facilitating their PRD writing and brainstorming processes.
# ```python
# import streamlit as st
# from transformers import pipeline
#
# # Function to generate text with caching to improve performance
# @st.cache(allow_output_mutation=True, show_spinner=False)
# def generate_text(input_text, model, max_length=500, num_return_sequences=1):
#     try:
#         response = model(input_text, max_length=max_length, num_return_sequences=num_return_sequences)
#         return [item['generated_text'] for item in response]
#     except Exception as e:
#         st.error(f"An error occurred: {str(e)}")
#         return []
#
# # Improved by loading only one instance of the model
# pipeline_generator = pipeline('text-generation', model='gpt2')
#
# st.title('GenAI Streamlit App for Product Managers')
#
# option = st.sidebar.selectbox(
#     "Choose a function:",
#     ("Create a PRD", "Improve the PRD", "Brainstorm on an Idea")
# )
#
# if option == "Create a PRD":
#     st.subheader("Create a PRD")
#     idea_input = st.text_area("Input your idea or keywords for the PRD:", height=150)
#     generate_button = st.button("Generate PRD")
#
#     if generate_button and idea_input:
#         with st.spinner('Generating...'):
#             generated_texts = generate_text(idea_input, pipeline_generator, num_return_sequences=1)
#             if generated_texts:
#                 st.text_area("Generated PRD:", value=generated_texts[0], height=300, help="You can edit the generated PRD here.")
#
# elif option == "Improve the PRD":
#     st.subheader("Improve the PRD")
#     prd_input = st.text_area("Paste your existing PRD here:", height=150)
#     improve_button = st.button("Improve PRD")
#
#     if improve_button and prd_input:
#         with st.spinner('Improving...'):
#             improved_texts = generate_text(prd_input, pipeline_generator, num_return_sequences=1)
#             if improved_texts:
#                 st.text_area("Improved PRD:", value=improved_texts[0], height=300, help="Review and further edit based on the suggestions.")
#
# elif option == "Brainstorm on an Idea":
#     st.subheader("Brainstorm on an Idea")
#     idea_description = st.text_area("Describe the problem or idea:", height=150)
#     brainstorm_button = st.button("Brainstorm Ideas")
#
#     if brainstorm_button and idea_description:
#         with st.spinner('Brainstorming...'):
#             brainstormed_ideas = generate_text(f"Brainstorm ideas based on: {idea_description}", pipeline_generator, num_return_sequences=3)
#             st.write("Brainstormed Ideas:")
#             for i, idea in enumerate(brainstormed_ideas, start=1):
#                 st.text_area(f"Idea {i}", value=idea, height=100, help="You can refine the idea here.")
# ```
